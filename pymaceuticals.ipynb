# %%
#*******************************************************************************************
 #
 #  File Name:  pymaceuticals.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, pymaceuticals.ipynb, reads from the folder, 
 #      resources, two csv files, mouse_study_data.csv and mouse_study_results.csv, 
 #      which contain data about a pharmaceutical company's most recent animal study. 
 #      In this study, two hundred forty-nine tumor-ridden mice, received treatment 
 #      from a range of drug regimens. Over the course of 45 days, technicians observed 
 #      and measured tumor development. The purpose of this study is to compare the 
 #      performance of Pymaceuticals’ drug of interest, Capomulin, against the other 
 #      treatment regimens. This Python script generates all of the tables and 
 #      figures needed for a technical report of this clinical study.
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/18/2023      Initial Development                     Nicholas J. George
 #
 #******************************************************************************************/

import logx
import matplotlibx
import pandasx
import pymaceuticalsx

import numpy as np
import pandas as pd

pd.options.mode.chained_assignment = None
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='24337a8b-f96d-4c49-90e2-600f7afcc317'>
#   <div id="cb177656-56a2-4412-a968-c9c20ce3fa34" data-root-id="24337a8b-f96d-4c49-90e2-600f7afcc317" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a5501f69-a2ad-49af-b3d5-33e301d5b5b1":{"version":"3.8.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"3779d30a-35b5-420e-9636-b069c15a93b3","attributes":{"notifications":{"type":"object","name":"Notifications","id":"9cb87095-c1b0-497c-9b3e-3bbe3aabe66e"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"24337a8b-f96d-4c49-90e2-600f7afcc317"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"79373f93-69e7-45d4-a8bc-82a25b2c244e","attributes":{"plot_id":"24337a8b-f96d-4c49-90e2-600f7afcc317","comm_id":"bc86f12066254b03b9d50d94ec176b90","client_comm_id":"45bda0083e4d40019b5c9861ae31e1dc"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"a5501f69-a2ad-49af-b3d5-33e301d5b5b1","roots":{"24337a8b-f96d-4c49-90e2-600f7afcc317":"cb177656-56a2-4412-a968-c9c20ce3fa34"},"root_ids":["24337a8b-f96d-4c49-90e2-600f7afcc317"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
CONSTANT_LOCAL_FILE_NAME = 'pymaceuticals.ipynb'


CONSTANT_MOUSE_INFO_CSV_FILE_PATH = './resources/mouse_study_data.csv'

CONSTANT_MEDICAL_STUDY_CSV_FILE_PATH = './resources/mouse_study_results.csv'


logx.set_log_mode(False)

logx.set_image_mode(False)


logx.begin_program('pymaceuticals')

# %% [markdown]
# # <br> **Section 1: Extraction**

# %% [markdown]
# ## **Section 1.1: Read CSV Files**

# %% [markdown]
# ###  **Create DataFrames**

# %%
data_type_dictionary \
    = {'Mouse ID': str,
       'Drug Regimen':	str,
       'Sex': str,
       'Age_months': int,
       'Weight (g)': float}

mouse_info_dataframe \
    = pd.read_csv(CONSTANT_MOUSE_INFO_CSV_FILE_PATH, dtype = data_type_dictionary)

logx.log_write_object(mouse_info_dataframe)

# %%
data_type_dictionary \
    = {'Mouse ID': str,
       'Timepoint': int,
       'Tumor Volume (mm3)': float,
       'Metastatic Sites': int}

mouse_study_dataframe \
    = pd.read_csv(CONSTANT_MEDICAL_STUDY_CSV_FILE_PATH, dtype = data_type_dictionary)

logx.log_write_object(mouse_study_dataframe)

# %% [markdown]
# ###  **Merge DataFrames**

# %%
complete_medical_study_dataframe \
    = pd.merge \
        (mouse_info_dataframe,
         mouse_study_dataframe,
         how = 'left',
         on = 'Mouse ID')

complete_medical_study_dataframe \
    .rename \
        (columns \
             = {'Mouse ID': 'mouse_id', 
                'Drug Regimen': 'drug_regimen',
                'Sex': 'sex',
                'Age_months': 'age_months',
                'Weight (g)': 'weight_grams',
                'Timepoint': 'timepoint',
                'Tumor Volume (mm3)': 'tumor_volume_mm3',
                'Metastatic Sites': 'metastatic_sites'},
         inplace = True)

complete_medical_study_dataframe['drug_regimen'] \
    = complete_medical_study_dataframe['drug_regimen'].str.upper()

logx.log_write_object(complete_medical_study_dataframe)

# %% [markdown]
# ### **Display Merged DataFrame**

# %%
pandasx.return_formatted_table \
    (complete_medical_study_dataframe,
     'Table 1.1: Complete Medical Study DataFrame')
# Out:
# <style type="text/css">
# #T_41833 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_41833_row0_col0, #T_41833_row0_col1, #T_41833_row0_col2, #T_41833_row0_col3, #T_41833_row0_col4, #T_41833_row0_col5, #T_41833_row0_col6, #T_41833_row0_col7, #T_41833_row1_col0, #T_41833_row1_col1, #T_41833_row1_col2, #T_41833_row1_col3, #T_41833_row1_col4, #T_41833_row1_col5, #T_41833_row1_col6, #T_41833_row1_col7, #T_41833_row2_col0, #T_41833_row2_col1, #T_41833_row2_col2, #T_41833_row2_col3, #T_41833_row2_col4, #T_41833_row2_col5, #T_41833_row2_col6, #T_41833_row2_col7, #T_41833_row3_col0, #T_41833_row3_col1, #T_41833_row3_col2, #T_41833_row3_col3, #T_41833_row3_col4, #T_41833_row3_col5, #T_41833_row3_col6, #T_41833_row3_col7, #T_41833_row4_col0, #T_41833_row4_col1, #T_41833_row4_col2, #T_41833_row4_col3, #T_41833_row4_col4, #T_41833_row4_col5, #T_41833_row4_col6, #T_41833_row4_col7, #T_41833_row5_col0, #T_41833_row5_col1, #T_41833_row5_col2, #T_41833_row5_col3, #T_41833_row5_col4, #T_41833_row5_col5, #T_41833_row5_col6, #T_41833_row5_col7, #T_41833_row6_col0, #T_41833_row6_col1, #T_41833_row6_col2, #T_41833_row6_col3, #T_41833_row6_col4, #T_41833_row6_col5, #T_41833_row6_col6, #T_41833_row6_col7, #T_41833_row7_col0, #T_41833_row7_col1, #T_41833_row7_col2, #T_41833_row7_col3, #T_41833_row7_col4, #T_41833_row7_col5, #T_41833_row7_col6, #T_41833_row7_col7, #T_41833_row8_col0, #T_41833_row8_col1, #T_41833_row8_col2, #T_41833_row8_col3, #T_41833_row8_col4, #T_41833_row8_col5, #T_41833_row8_col6, #T_41833_row8_col7, #T_41833_row9_col0, #T_41833_row9_col1, #T_41833_row9_col2, #T_41833_row9_col3, #T_41833_row9_col4, #T_41833_row9_col5, #T_41833_row9_col6, #T_41833_row9_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_41833">
#   <caption>Table 1.1: Complete Medical Study DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_41833_level0_col0" class="col_heading level0 col0" >mouse_id</th>
#       <th id="T_41833_level0_col1" class="col_heading level0 col1" >drug_regimen</th>
#       <th id="T_41833_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_41833_level0_col3" class="col_heading level0 col3" >age_months</th>
#       <th id="T_41833_level0_col4" class="col_heading level0 col4" >weight_grams</th>
#       <th id="T_41833_level0_col5" class="col_heading level0 col5" >timepoint</th>
#       <th id="T_41833_level0_col6" class="col_heading level0 col6" >tumor_volume_mm3</th>
#       <th id="T_41833_level0_col7" class="col_heading level0 col7" >metastatic_sites</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41833_row0_col0" class="data row0 col0" >k403</td>
#       <td id="T_41833_row0_col1" class="data row0 col1" >RAMICANE</td>
#       <td id="T_41833_row0_col2" class="data row0 col2" >Male</td>
#       <td id="T_41833_row0_col3" class="data row0 col3" >21</td>
#       <td id="T_41833_row0_col4" class="data row0 col4" >16.00</td>
#       <td id="T_41833_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_41833_row0_col6" class="data row0 col6" >45.00</td>
#       <td id="T_41833_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row1_col0" class="data row1 col0" >k403</td>
#       <td id="T_41833_row1_col1" class="data row1 col1" >RAMICANE</td>
#       <td id="T_41833_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_41833_row1_col3" class="data row1 col3" >21</td>
#       <td id="T_41833_row1_col4" class="data row1 col4" >16.00</td>
#       <td id="T_41833_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_41833_row1_col6" class="data row1 col6" >38.83</td>
#       <td id="T_41833_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row2_col0" class="data row2 col0" >k403</td>
#       <td id="T_41833_row2_col1" class="data row2 col1" >RAMICANE</td>
#       <td id="T_41833_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_41833_row2_col3" class="data row2 col3" >21</td>
#       <td id="T_41833_row2_col4" class="data row2 col4" >16.00</td>
#       <td id="T_41833_row2_col5" class="data row2 col5" >10</td>
#       <td id="T_41833_row2_col6" class="data row2 col6" >35.01</td>
#       <td id="T_41833_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row3_col0" class="data row3 col0" >k403</td>
#       <td id="T_41833_row3_col1" class="data row3 col1" >RAMICANE</td>
#       <td id="T_41833_row3_col2" class="data row3 col2" >Male</td>
#       <td id="T_41833_row3_col3" class="data row3 col3" >21</td>
#       <td id="T_41833_row3_col4" class="data row3 col4" >16.00</td>
#       <td id="T_41833_row3_col5" class="data row3 col5" >15</td>
#       <td id="T_41833_row3_col6" class="data row3 col6" >34.22</td>
#       <td id="T_41833_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row4_col0" class="data row4 col0" >k403</td>
#       <td id="T_41833_row4_col1" class="data row4 col1" >RAMICANE</td>
#       <td id="T_41833_row4_col2" class="data row4 col2" >Male</td>
#       <td id="T_41833_row4_col3" class="data row4 col3" >21</td>
#       <td id="T_41833_row4_col4" class="data row4 col4" >16.00</td>
#       <td id="T_41833_row4_col5" class="data row4 col5" >20</td>
#       <td id="T_41833_row4_col6" class="data row4 col6" >33.00</td>
#       <td id="T_41833_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row5_col0" class="data row5 col0" >k403</td>
#       <td id="T_41833_row5_col1" class="data row5 col1" >RAMICANE</td>
#       <td id="T_41833_row5_col2" class="data row5 col2" >Male</td>
#       <td id="T_41833_row5_col3" class="data row5 col3" >21</td>
#       <td id="T_41833_row5_col4" class="data row5 col4" >16.00</td>
#       <td id="T_41833_row5_col5" class="data row5 col5" >25</td>
#       <td id="T_41833_row5_col6" class="data row5 col6" >33.46</td>
#       <td id="T_41833_row5_col7" class="data row5 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row6_col0" class="data row6 col0" >k403</td>
#       <td id="T_41833_row6_col1" class="data row6 col1" >RAMICANE</td>
#       <td id="T_41833_row6_col2" class="data row6 col2" >Male</td>
#       <td id="T_41833_row6_col3" class="data row6 col3" >21</td>
#       <td id="T_41833_row6_col4" class="data row6 col4" >16.00</td>
#       <td id="T_41833_row6_col5" class="data row6 col5" >30</td>
#       <td id="T_41833_row6_col6" class="data row6 col6" >31.10</td>
#       <td id="T_41833_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row7_col0" class="data row7 col0" >k403</td>
#       <td id="T_41833_row7_col1" class="data row7 col1" >RAMICANE</td>
#       <td id="T_41833_row7_col2" class="data row7 col2" >Male</td>
#       <td id="T_41833_row7_col3" class="data row7 col3" >21</td>
#       <td id="T_41833_row7_col4" class="data row7 col4" >16.00</td>
#       <td id="T_41833_row7_col5" class="data row7 col5" >35</td>
#       <td id="T_41833_row7_col6" class="data row7 col6" >26.55</td>
#       <td id="T_41833_row7_col7" class="data row7 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row8_col0" class="data row8 col0" >k403</td>
#       <td id="T_41833_row8_col1" class="data row8 col1" >RAMICANE</td>
#       <td id="T_41833_row8_col2" class="data row8 col2" >Male</td>
#       <td id="T_41833_row8_col3" class="data row8 col3" >21</td>
#       <td id="T_41833_row8_col4" class="data row8 col4" >16.00</td>
#       <td id="T_41833_row8_col5" class="data row8 col5" >40</td>
#       <td id="T_41833_row8_col6" class="data row8 col6" >24.37</td>
#       <td id="T_41833_row8_col7" class="data row8 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_41833_row9_col0" class="data row9 col0" >k403</td>
#       <td id="T_41833_row9_col1" class="data row9 col1" >RAMICANE</td>
#       <td id="T_41833_row9_col2" class="data row9 col2" >Male</td>
#       <td id="T_41833_row9_col3" class="data row9 col3" >21</td>
#       <td id="T_41833_row9_col4" class="data row9 col4" >16.00</td>
#       <td id="T_41833_row9_col5" class="data row9 col5" >

# %% [markdown]
# ## **Section 1.2: Remove Mouse IDs with Duplicate Timepoints**

# %% [markdown]
# ### **Display the Number of Unique Mouse IDs**

# %%
unique_mouse_id_count_integer = complete_medical_study_dataframe['mouse_id'].nunique()

logx.print_and_log_text \
    ('\033[1m' \
     + 'The number of unique mouse IDs in the complete medical study DataFrame is ' \
     + '{:,}.'.format(unique_mouse_id_count_integer) \
     + '\033[0m')
# Out:
# The number of unique mouse IDs in the complete medical study DataFrame is 249.

# %% [markdown]
# ### **Check for Any Mouse IDs with Duplicate Timepoints**

# %%
duplicate_mouse_dataframe \
    = complete_medical_study_dataframe \
        [complete_medical_study_dataframe.duplicated(subset = ['mouse_id', 'timepoint'])]

logx.log_write_object(duplicate_mouse_dataframe)

# %% [markdown]
# ### **Display Mouse IDs with Duplicate Timepoints**

# %%
pandasx.return_formatted_table \
    (duplicate_mouse_dataframe,
     'Table 1.2.1: Mouse IDs with Duplicate Timepoints')
# Out:
# <style type="text/css">
# #T_9d710 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_9d710_row0_col0, #T_9d710_row0_col1, #T_9d710_row0_col2, #T_9d710_row0_col3, #T_9d710_row0_col4, #T_9d710_row0_col5, #T_9d710_row0_col6, #T_9d710_row0_col7, #T_9d710_row1_col0, #T_9d710_row1_col1, #T_9d710_row1_col2, #T_9d710_row1_col3, #T_9d710_row1_col4, #T_9d710_row1_col5, #T_9d710_row1_col6, #T_9d710_row1_col7, #T_9d710_row2_col0, #T_9d710_row2_col1, #T_9d710_row2_col2, #T_9d710_row2_col3, #T_9d710_row2_col4, #T_9d710_row2_col5, #T_9d710_row2_col6, #T_9d710_row2_col7, #T_9d710_row3_col0, #T_9d710_row3_col1, #T_9d710_row3_col2, #T_9d710_row3_col3, #T_9d710_row3_col4, #T_9d710_row3_col5, #T_9d710_row3_col6, #T_9d710_row3_col7, #T_9d710_row4_col0, #T_9d710_row4_col1, #T_9d710_row4_col2, #T_9d710_row4_col3, #T_9d710_row4_col4, #T_9d710_row4_col5, #T_9d710_row4_col6, #T_9d710_row4_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_9d710">
#   <caption>Table 1.2.1: Mouse IDs with Duplicate Timepoints</caption>
#   <thead>
#     <tr>
#       <th id="T_9d710_level0_col0" class="col_heading level0 col0" >mouse_id</th>
#       <th id="T_9d710_level0_col1" class="col_heading level0 col1" >drug_regimen</th>
#       <th id="T_9d710_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_9d710_level0_col3" class="col_heading level0 col3" >age_months</th>
#       <th id="T_9d710_level0_col4" class="col_heading level0 col4" >weight_grams</th>
#       <th id="T_9d710_level0_col5" class="col_heading level0 col5" >timepoint</th>
#       <th id="T_9d710_level0_col6" class="col_heading level0 col6" >tumor_volume_mm3</th>
#       <th id="T_9d710_level0_col7" class="col_heading level0 col7" >metastatic_sites</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9d710_row0_col0" class="data row0 col0" >g989</td>
#       <td id="T_9d710_row0_col1" class="data row0 col1" >PROPRIVA</td>
#       <td id="T_9d710_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_9d710_row0_col3" class="data row0 col3" >21</td>
#       <td id="T_9d710_row0_col4" class="data row0 col4" >26.00</td>
#       <td id="T_9d710_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_9d710_row0_col6" class="data row0 col6" >45.00</td>
#       <td id="T_9d710_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_9d710_row1_col0" class="data row1 col0" >g989</td>
#       <td id="T_9d710_row1_col1" class="data row1 col1" >PROPRIVA</td>
#       <td id="T_9d710_row1_col2" class="data row1 col2" >Female</td>
#       <td id="T_9d710_row1_col3" class="data row1 col3" >21</td>
#       <td id="T_9d710_row1_col4" class="data row1 col4" >26.00</td>
#       <td id="T_9d710_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_9d710_row1_col6" class="data row1 col6" >47.57</td>
#       <td id="T_9d710_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_9d710_row2_col0" class="data row2 col0" >g989</td>
#       <td id="T_9d710_row2_col1" class="data row2 col1" >PROPRIVA</td>
#       <td id="T_9d710_row2_col2" class="data row2 col2" >Female</td>
#       <td id="T_9d710_row2_col3" class="data row2 col3" >21</td>
#       <td id="T_9d710_row2_col4" class="data row2 col4" >26.00</td>
#       <td id="T_9d710_row2_col5" class="data row2 col5" >10</td>
#       <td id="T_9d710_row2_col6" class="data row2 col6" >49.88</td>
#       <td id="T_9d710_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_9d710_row3_col0" class="data row3 col0" >g989</td>
#       <td id="T_9d710_row3_col1" class="data row3 col1" >PROPRIVA</td>
#       <td id="T_9d710_row3_col2" class="data row3 col2" >Female</td>
#       <td id="T_9d710_row3_col3" class="data row3 col3" >21</td>
#       <td id="T_9d710_row3_col4" class="data row3 col4" >26.00</td>
#       <td id="T_9d710_row3_col5" class="data row3 col5" >15</td>
#       <td id="T_9d710_row3_col6" class="data row3 col6" >53.44</td>
#       <td id="T_9d710_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_9d710_row4_col0" class="data row4 col0" >g989</td>
#       <td id="T_9d710_row4_col1" class="data row4 col1" >PROPRIVA</td>
#       <td id="T_9d710_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_9d710_row4_col3" class="data row4 col3" >21</td>
#       <td id="T_9d710_row4_col4" class="data row4 col4" >26.00</td>
#       <td id="T_9d710_row4_col5" class="data row4 col5" >20</td>
#       <td id="T_9d710_row4_col6" class="data row4 col6" >54.66</td>
#       <td id="T_9d710_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Display All Mouse IDs with Duplicate Timepoints Records**

# %%
duplicate_mouse_id_string_list \
    = duplicate_mouse_dataframe['mouse_id'].unique().tolist()

logx.log_write_object(duplicate_mouse_id_string_list)

# %%
temp_dataframe \
    = complete_medical_study_dataframe \
        .apply \
            (lambda row: \
                 row[complete_medical_study_dataframe['mouse_id'].isin(duplicate_mouse_id_string_list)])

pandasx.return_formatted_table \
    (temp_dataframe, 'Table 1.2.2: All Mouse IDs with Duplicate Timepoints Records')
# Out:
# <style type="text/css">
# #T_afe99 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_afe99_row0_col0, #T_afe99_row0_col1, #T_afe99_row0_col2, #T_afe99_row0_col3, #T_afe99_row0_col4, #T_afe99_row0_col5, #T_afe99_row0_col6, #T_afe99_row0_col7, #T_afe99_row1_col0, #T_afe99_row1_col1, #T_afe99_row1_col2, #T_afe99_row1_col3, #T_afe99_row1_col4, #T_afe99_row1_col5, #T_afe99_row1_col6, #T_afe99_row1_col7, #T_afe99_row2_col0, #T_afe99_row2_col1, #T_afe99_row2_col2, #T_afe99_row2_col3, #T_afe99_row2_col4, #T_afe99_row2_col5, #T_afe99_row2_col6, #T_afe99_row2_col7, #T_afe99_row3_col0, #T_afe99_row3_col1, #T_afe99_row3_col2, #T_afe99_row3_col3, #T_afe99_row3_col4, #T_afe99_row3_col5, #T_afe99_row3_col6, #T_afe99_row3_col7, #T_afe99_row4_col0, #T_afe99_row4_col1, #T_afe99_row4_col2, #T_afe99_row4_col3, #T_afe99_row4_col4, #T_afe99_row4_col5, #T_afe99_row4_col6, #T_afe99_row4_col7, #T_afe99_row5_col0, #T_afe99_row5_col1, #T_afe99_row5_col2, #T_afe99_row5_col3, #T_afe99_row5_col4, #T_afe99_row5_col5, #T_afe99_row5_col6, #T_afe99_row5_col7, #T_afe99_row6_col0, #T_afe99_row6_col1, #T_afe99_row6_col2, #T_afe99_row6_col3, #T_afe99_row6_col4, #T_afe99_row6_col5, #T_afe99_row6_col6, #T_afe99_row6_col7, #T_afe99_row7_col0, #T_afe99_row7_col1, #T_afe99_row7_col2, #T_afe99_row7_col3, #T_afe99_row7_col4, #T_afe99_row7_col5, #T_afe99_row7_col6, #T_afe99_row7_col7, #T_afe99_row8_col0, #T_afe99_row8_col1, #T_afe99_row8_col2, #T_afe99_row8_col3, #T_afe99_row8_col4, #T_afe99_row8_col5, #T_afe99_row8_col6, #T_afe99_row8_col7, #T_afe99_row9_col0, #T_afe99_row9_col1, #T_afe99_row9_col2, #T_afe99_row9_col3, #T_afe99_row9_col4, #T_afe99_row9_col5, #T_afe99_row9_col6, #T_afe99_row9_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_afe99">
#   <caption>Table 1.2.2: All Mouse IDs with Duplicate Timepoints Records</caption>
#   <thead>
#     <tr>
#       <th id="T_afe99_level0_col0" class="col_heading level0 col0" >mouse_id</th>
#       <th id="T_afe99_level0_col1" class="col_heading level0 col1" >drug_regimen</th>
#       <th id="T_afe99_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_afe99_level0_col3" class="col_heading level0 col3" >age_months</th>
#       <th id="T_afe99_level0_col4" class="col_heading level0 col4" >weight_grams</th>
#       <th id="T_afe99_level0_col5" class="col_heading level0 col5" >timepoint</th>
#       <th id="T_afe99_level0_col6" class="col_heading level0 col6" >tumor_volume_mm3</th>
#       <th id="T_afe99_level0_col7" class="col_heading level0 col7" >metastatic_sites</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_afe99_row0_col0" class="data row0 col0" >g989</td>
#       <td id="T_afe99_row0_col1" class="data row0 col1" >PROPRIVA</td>
#       <td id="T_afe99_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_afe99_row0_col3" class="data row0 col3" >21</td>
#       <td id="T_afe99_row0_col4" class="data row0 col4" >26.00</td>
#       <td id="T_afe99_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_afe99_row0_col6" class="data row0 col6" >45.00</td>
#       <td id="T_afe99_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row1_col0" class="data row1 col0" >g989</td>
#       <td id="T_afe99_row1_col1" class="data row1 col1" >PROPRIVA</td>
#       <td id="T_afe99_row1_col2" class="data row1 col2" >Female</td>
#       <td id="T_afe99_row1_col3" class="data row1 col3" >21</td>
#       <td id="T_afe99_row1_col4" class="data row1 col4" >26.00</td>
#       <td id="T_afe99_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_afe99_row1_col6" class="data row1 col6" >45.00</td>
#       <td id="T_afe99_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row2_col0" class="data row2 col0" >g989</td>
#       <td id="T_afe99_row2_col1" class="data row2 col1" >PROPRIVA</td>
#       <td id="T_afe99_row2_col2" class="data row2 col2" >Female</td>
#       <td id="T_afe99_row2_col3" class="data row2 col3" >21</td>
#       <td id="T_afe99_row2_col4" class="data row2 col4" >26.00</td>
#       <td id="T_afe99_row2_col5" class="data row2 col5" >5</td>
#       <td id="T_afe99_row2_col6" class="data row2 col6" >48.79</td>
#       <td id="T_afe99_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row3_col0" class="data row3 col0" >g989</td>
#       <td id="T_afe99_row3_col1" class="data row3 col1" >PROPRIVA</td>
#       <td id="T_afe99_row3_col2" class="data row3 col2" >Female</td>
#       <td id="T_afe99_row3_col3" class="data row3 col3" >21</td>
#       <td id="T_afe99_row3_col4" class="data row3 col4" >26.00</td>
#       <td id="T_afe99_row3_col5" class="data row3 col5" >5</td>
#       <td id="T_afe99_row3_col6" class="data row3 col6" >47.57</td>
#       <td id="T_afe99_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row4_col0" class="data row4 col0" >g989</td>
#       <td id="T_afe99_row4_col1" class="data row4 col1" >PROPRIVA</td>
#       <td id="T_afe99_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_afe99_row4_col3" class="data row4 col3" >21</td>
#       <td id="T_afe99_row4_col4" class="data row4 col4" >26.00</td>
#       <td id="T_afe99_row4_col5" class="data row4 col5" >10</td>
#       <td id="T_afe99_row4_col6" class="data row4 col6" >51.75</td>
#       <td id="T_afe99_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row5_col0" class="data row5 col0" >g989</td>
#       <td id="T_afe99_row5_col1" class="data row5 col1" >PROPRIVA</td>
#       <td id="T_afe99_row5_col2" class="data row5 col2" >Female</td>
#       <td id="T_afe99_row5_col3" class="data row5 col3" >21</td>
#       <td id="T_afe99_row5_col4" class="data row5 col4" >26.00</td>
#       <td id="T_afe99_row5_col5" class="data row5 col5" >10</td>
#       <td id="T_afe99_row5_col6" class="data row5 col6" >49.88</td>
#       <td id="T_afe99_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row6_col0" class="data row6 col0" >g989</td>
#       <td id="T_afe99_row6_col1" class="data row6 col1" >PROPRIVA</td>
#       <td id="T_afe99_row6_col2" class="data row6 col2" >Female</td>
#       <td id="T_afe99_row6_col3" class="data row6 col3" >21</td>
#       <td id="T_afe99_row6_col4" class="data row6 col4" >26.00</td>
#       <td id="T_afe99_row6_col5" class="data row6 col5" >15</td>
#       <td id="T_afe99_row6_col6" class="data row6 col6" >51.33</td>
#       <td id="T_afe99_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row7_col0" class="data row7 col0" >g989</td>
#       <td id="T_afe99_row7_col1" class="data row7 col1" >PROPRIVA</td>
#       <td id="T_afe99_row7_col2" class="data row7 col2" >Female</td>
#       <td id="T_afe99_row7_col3" class="data row7 col3" >21</td>
#       <td id="T_afe99_row7_col4" class="data row7 col4" >26.00</td>
#       <td id="T_afe99_row7_col5" class="data row7 col5" >15</td>
#       <td id="T_afe99_row7_col6" class="data row7 col6" >53.44</td>
#       <td id="T_afe99_row7_col7" class="data row7 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row8_col0" class="data row8 col0" >g989</td>
#       <td id="T_afe99_row8_col1" class="data row8 col1" >PROPRIVA</td>
#       <td id="T_afe99_row8_col2" class="data row8 col2" >Female</td>
#       <td id="T_afe99_row8_col3" class="data row8 col3" >21</td>
#       <td id="T_afe99_row8_col4" class="data row8 col4" >26.00</td>
#       <td id="T_afe99_row8_col5" class="data row8 col5" >20</td>
#       <td id="T_afe99_row8_col6" class="data row8 col6" >55.33</td>
#       <td id="T_afe99_row8_col7" class="data row8 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_afe99_row9_col0" class="data row9 col0" >g989</td>
#       <td id="T_afe99_row9_col1" class="data row9 col1" >PROPRIVA</td>
#       <td id="T_afe99_row9_col2" class="data row9 col2" >Female</td>
#       <td id="T_afe99_row9_col3" class="data row9 col3" >21</td>
#       <td id="T_afe99_row9_col4" class="data row9 col4" >26.00</td>
#       <td id="T_afe99_

# %% [markdown]
# ### **Clean Medical Study DataFrame without Mouse IDs with Duplicate Timepoints Records**

# %%
clean_medical_study_dataframe \
    = complete_medical_study_dataframe \
        .apply \
            (lambda row: \
                 row[~complete_medical_study_dataframe['mouse_id'].isin(duplicate_mouse_id_string_list)])

logx.log_write_object(clean_medical_study_dataframe)

# %% [markdown]
# ### **Display the Updated Number of Unique Mouse IDs**

# %%
unique_mouse_id_count_integer = clean_medical_study_dataframe['mouse_id'].nunique()

logx.print_and_log_text \
    ('\033[1m' \
     + 'The updated number of unique mouse IDs in the complete medical study ' \
     + 'DataFrame is {:,}.'.format(unique_mouse_id_count_integer) \
     + '\033[0m')
# Out:
# The updated number of unique mouse IDs in the complete medical study DataFrame is 248.

# %% [markdown]
# # <br> **Section 2: Tumor Volume Summary Statistics**

# %% [markdown]
# ## **Section 2.1: Statistical Calculations**

# %% [markdown]
# ### **New Medical Study DataFrame Grouped by Drug Regimen**

# %%
grouped_by_regimen_dataframe = clean_medical_study_dataframe.groupby('drug_regimen')

logx.log_write_object(grouped_by_regimen_dataframe)

# %% [markdown]
# ### **Tumor Volume (Mean)**

# %%
mean_tumor_volume_series = grouped_by_regimen_dataframe['tumor_volume_mm3'].mean()

logx.log_write_object(mean_tumor_volume_series)

# %% [markdown]
# ### **Tumor Volume (Median)**

# %%
median_tumor_volume_series = grouped_by_regimen_dataframe['tumor_volume_mm3'].median()

logx.log_write_object(median_tumor_volume_series)

# %% [markdown]
# ### **Tumor Volume (Variance)**

# %%
variance_tumor_volume_series = grouped_by_regimen_dataframe['tumor_volume_mm3'].var()

logx.log_write_object(variance_tumor_volume_series)

# %% [markdown]
# ### **Tumor Volume (Standard Deviation)**

# %%
std_tumor_volume_series = grouped_by_regimen_dataframe['tumor_volume_mm3'].std()

logx.log_write_object(std_tumor_volume_series)

# %% [markdown]
# ### **Tumor Volume (Standard Errror of the Mean)**

# %%
sem_tumor_volume_series = grouped_by_regimen_dataframe['tumor_volume_mm3'].sem()

logx.log_write_object(sem_tumor_volume_series)

# %% [markdown]
# ### **Tumor Volume Summary Statistics DataFrame**

# %%
tumor_volume_statistics_dataframe \
    = pd.DataFrame \
        ({'mean': mean_tumor_volume_series,
          'median': median_tumor_volume_series,
          'variance': variance_tumor_volume_series,
          'std': std_tumor_volume_series,
          'sem': sem_tumor_volume_series})

logx.log_write_object(tumor_volume_statistics_dataframe)

# %% [markdown]
# ## **Section 2.2: Display Summary Statistics (Tumor Volume)**

# %% [markdown]
# ### **Display Summary Statistics**

# %%
pandasx.return_formatted_table \
    (tumor_volume_statistics_dataframe, 'Table 2.2.1: Summary Statistics (Tumor Volume)')
# Out:
# <style type="text/css">
# #T_1e427 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1e427_row0_col0, #T_1e427_row0_col1, #T_1e427_row0_col2, #T_1e427_row0_col3, #T_1e427_row0_col4, #T_1e427_row1_col0, #T_1e427_row1_col1, #T_1e427_row1_col2, #T_1e427_row1_col3, #T_1e427_row1_col4, #T_1e427_row2_col0, #T_1e427_row2_col1, #T_1e427_row2_col2, #T_1e427_row2_col3, #T_1e427_row2_col4, #T_1e427_row3_col0, #T_1e427_row3_col1, #T_1e427_row3_col2, #T_1e427_row3_col3, #T_1e427_row3_col4, #T_1e427_row4_col0, #T_1e427_row4_col1, #T_1e427_row4_col2, #T_1e427_row4_col3, #T_1e427_row4_col4, #T_1e427_row5_col0, #T_1e427_row5_col1, #T_1e427_row5_col2, #T_1e427_row5_col3, #T_1e427_row5_col4, #T_1e427_row6_col0, #T_1e427_row6_col1, #T_1e427_row6_col2, #T_1e427_row6_col3, #T_1e427_row6_col4, #T_1e427_row7_col0, #T_1e427_row7_col1, #T_1e427_row7_col2, #T_1e427_row7_col3, #T_1e427_row7_col4, #T_1e427_row8_col0, #T_1e427_row8_col1, #T_1e427_row8_col2, #T_1e427_row8_col3, #T_1e427_row8_col4, #T_1e427_row9_col0, #T_1e427_row9_col1, #T_1e427_row9_col2, #T_1e427_row9_col3, #T_1e427_row9_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_1e427">
#   <caption>Table 2.2.1: Summary Statistics (Tumor Volume)</caption>
#   <thead>
#     <tr>
#       <th id="T_1e427_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_1e427_level0_col1" class="col_heading level0 col1" >median</th>
#       <th id="T_1e427_level0_col2" class="col_heading level0 col2" >variance</th>
#       <th id="T_1e427_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_1e427_level0_col4" class="col_heading level0 col4" >sem</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1e427_row0_col0" class="data row0 col0" >40.68</td>
#       <td id="T_1e427_row0_col1" class="data row0 col1" >41.56</td>
#       <td id="T_1e427_row0_col2" class="data row0 col2" >24.95</td>
#       <td id="T_1e427_row0_col3" class="data row0 col3" >4.99</td>
#       <td id="T_1e427_row0_col4" class="data row0 col4" >0.33</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row1_col0" class="data row1 col0" >52.59</td>
#       <td id="T_1e427_row1_col1" class="data row1 col1" >51.78</td>
#       <td id="T_1e427_row1_col2" class="data row1 col2" >39.29</td>
#       <td id="T_1e427_row1_col3" class="data row1 col3" >6.27</td>
#       <td id="T_1e427_row1_col4" class="data row1 col4" >0.47</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row2_col0" class="data row2 col0" >52.88</td>
#       <td id="T_1e427_row2_col1" class="data row2 col1" >51.82</td>
#       <td id="T_1e427_row2_col2" class="data row2 col2" >43.13</td>
#       <td id="T_1e427_row2_col3" class="data row2 col3" >6.57</td>
#       <td id="T_1e427_row2_col4" class="data row2 col4" >0.49</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row3_col0" class="data row3 col0" >55.24</td>
#       <td id="T_1e427_row3_col1" class="data row3 col1" >53.70</td>
#       <td id="T_1e427_row3_col2" class="data row3 col2" >68.55</td>
#       <td id="T_1e427_row3_col3" class="data row3 col3" >8.28</td>
#       <td id="T_1e427_row3_col4" class="data row3 col4" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row4_col0" class="data row4 col0" >54.33</td>
#       <td id="T_1e427_row4_col1" class="data row4 col1" >52.51</td>
#       <td id="T_1e427_row4_col2" class="data row4 col2" >66.17</td>
#       <td id="T_1e427_row4_col3" class="data row4 col3" >8.13</td>
#       <td id="T_1e427_row4_col4" class="data row4 col4" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row5_col0" class="data row5 col0" >54.03</td>
#       <td id="T_1e427_row5_col1" class="data row5 col1" >52.29</td>
#       <td id="T_1e427_row5_col2" class="data row5 col2" >61.17</td>
#       <td id="T_1e427_row5_col3" class="data row5 col3" >7.82</td>
#       <td id="T_1e427_row5_col4" class="data row5 col4" >0.58</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row6_col0" class="data row6 col0" >52.32</td>
#       <td id="T_1e427_row6_col1" class="data row6 col1" >50.45</td>
#       <td id="T_1e427_row6_col2" class="data row6 col2" >43.85</td>
#       <td id="T_1e427_row6_col3" class="data row6 col3" >6.62</td>
#       <td id="T_1e427_row6_col4" class="data row6 col4" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row7_col0" class="data row7 col0" >40.22</td>
#       <td id="T_1e427_row7_col1" class="data row7 col1" >40.67</td>
#       <td id="T_1e427_row7_col2" class="data row7 col2" >23.49</td>
#       <td id="T_1e427_row7_col3" class="data row7 col3" >4.85</td>
#       <td id="T_1e427_row7_col4" class="data row7 col4" >0.32</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row8_col0" class="data row8 col0" >54.23</td>
#       <td id="T_1e427_row8_col1" class="data row8 col1" >52.43</td>
#       <td id="T_1e427_row8_col2" class="data row8 col2" >59.45</td>
#       <td id="T_1e427_row8_col3" class="data row8 col3" >7.71</td>
#       <td id="T_1e427_row8_col4" class="data row8 col4" >0.57</td>
#     </tr>
#     <tr>
#       <td id="T_1e427_row9_col0" class="data row9 col0" >53.24</td>
#       <td id="T_1e427_row9_col1" class="data row9 col1" >51.82</td>
#       <td id="T_1e427_row9_col2" class="data row9 col2" >48.53</td>
#       <td id="T_1e427_row9_col3" class="data row9 col3" >6.97</td>
#       <td id="T_1e427_row9_col4" class="data row9 col4" >0.52</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  # <br> **Section 3: Tumor Volume Over Time Per Drug Regimen**

# %% [markdown]
# ## **Section 3.1: Medical Study DataFrame by Drug Regimen**

# %% [markdown]
# ### **Medical Study DataFrame (Capomulin)**

# %%
capomulin_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'CAPOMULIN'), :]

logx.log_write_object(capomulin_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Ceftamin)**

# %%
ceftamin_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'CEFTAMIN'), :]

logx.log_write_object(ceftamin_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Infubinol)**

# %%
infubinol_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'INFUBINOL'), :]

logx.log_write_object(infubinol_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Ketapril)**

# %%
ketapril_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'KETAPRIL'), :]

logx.log_write_object(ketapril_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Naftisol)**

# %%
naftisol_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'NAFTISOL'), :]

logx.log_write_object(naftisol_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Placebo)**

# %%
placebo_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'PLACEBO'), :]

logx.log_write_object(placebo_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Propriva)**

# %%
propriva_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'PROPRIVA'), :]

logx.log_write_object(propriva_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Ramicane)**

# %%
ramicane_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'RAMICANE'), :]

logx.log_write_object(ramicane_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Stelasyn)**

# %%
stelasyn_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'STELASYN'), :]

logx.log_write_object(stelasyn_study_dataframe)

# %% [markdown]
# ### **Medical Study DataFrame (Zoniferol)**

# %%
zoniferol_study_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'ZONIFEROL'), :]

logx.log_write_object(zoniferol_study_dataframe)

# %% [markdown]
# ## **Section 3.2: Random Mouse ID by Drug Regimen**

# %% [markdown]
# ### **Random Mouse ID Selection (Capomulin)**

# %%
rmid_capomulin_string \
    = capomulin_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_capomulin_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Ceftamin)**

# %%
rmid_ceftamin_string \
    = ceftamin_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_ceftamin_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Infubinol)**

# %%
rmid_infubinol_string \
    = infubinol_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_infubinol_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Ketapril)**

# %%
rmid_ketapril_string \
    = ketapril_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_ketapril_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Naftisol)**

# %%
rmid_naftisol_string \
    = naftisol_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_naftisol_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Placebo)**

# %%
rmid_placebo_string \
    = placebo_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_placebo_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Propriva)**

# %%
rmid_propriva_string \
    = propriva_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_propriva_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Ramicane)**

# %%
rmid_ramicane_string \
    = ramicane_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_ramicane_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Stelasyn)**

# %%
rmid_stelasyn_string \
    = stelasyn_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_stelasyn_string)

# %% [markdown]
# ### **Random Mouse ID Selection (Zoniferol)**

# %%
rmid_zoniferol_string \
    = zoniferol_study_dataframe.sample(n = 1, replace = False).iloc[0, 0]

logx.log_write_object(rmid_zoniferol_string)

# %% [markdown]
# ## **Section 3.3: Mouse Record Retrievel by Drug Regimen**

# %% [markdown]
# ### **Mouse Data Retrieval (Capomulin)**

# %%
capomulin_mouse_dataframe \
    = capomulin_study_dataframe.loc[(capomulin_study_dataframe['mouse_id'] == rmid_capomulin_string), :]

logx.log_write_object(capomulin_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Ceftamin)**

# %%
ceftamin_mouse_dataframe \
    = ceftamin_study_dataframe.loc[(ceftamin_study_dataframe['mouse_id'] == rmid_ceftamin_string), :]

logx.log_write_object(ceftamin_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Infubinol)**

# %%
infubinol_mouse_dataframe \
    = infubinol_study_dataframe.loc[(infubinol_study_dataframe['mouse_id'] == rmid_infubinol_string), :]

logx.log_write_object(infubinol_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Ketapril)**

# %%
ketapril_mouse_dataframe \
    = ketapril_study_dataframe.loc[(ketapril_study_dataframe['mouse_id'] == rmid_ketapril_string), :]

logx.log_write_object(ketapril_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Naftisol)**

# %%
naftisol_mouse_dataframe \
    = naftisol_study_dataframe.loc[(naftisol_study_dataframe['mouse_id'] == rmid_naftisol_string), :]

logx.log_write_object(naftisol_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Placebo)**

# %%
placebo_mouse_dataframe \
    = placebo_study_dataframe.loc[(placebo_study_dataframe['mouse_id'] == rmid_placebo_string), :]

logx.log_write_object(placebo_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Propriva)**

# %%
propriva_mouse_dataframe \
    = propriva_study_dataframe.loc[(propriva_study_dataframe['mouse_id'] == rmid_propriva_string), :]

logx.log_write_object(propriva_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Ramicane)**

# %%
ramicane_mouse_dataframe \
    = ramicane_study_dataframe.loc[(ramicane_study_dataframe['mouse_id'] == rmid_ramicane_string), :]

logx.log_write_object(ramicane_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Stelasyn)**

# %%
stelasyn_mouse_dataframe \
    = stelasyn_study_dataframe.loc[(stelasyn_study_dataframe['mouse_id'] == rmid_stelasyn_string), :]

logx.log_write_object(stelasyn_mouse_dataframe)

# %% [markdown]
# ### **Mouse Data Retrieval (Zoniferol)**

# %%
zoniferol_mouse_dataframe \
    = zoniferol_study_dataframe.loc[(zoniferol_study_dataframe['mouse_id'] == rmid_zoniferol_string), :]

logx.log_write_object(zoniferol_mouse_dataframe)

# %% [markdown]
# ## **Section 3.4: Line Calculations by Drug Regimen**

# %% [markdown]
# ### **Line Calculations (Capomulin)**

# %%
capomulin_x_series = capomulin_mouse_dataframe['timepoint']

logx.log_write_object(capomulin_x_series)

# %%
capomulin_y_series = capomulin_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(capomulin_y_series)

# %% [markdown]
# ### **Line Calculations (Ceftamin)**

# %%
ceftamin_x_series = ceftamin_mouse_dataframe['timepoint']

logx.log_write_object(ceftamin_x_series)

# %%
ceftamin_y_series = ceftamin_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(ceftamin_y_series)

# %% [markdown]
# ### **Line Calculations (Infubinol)**

# %%
infubinol_x_series = infubinol_mouse_dataframe['timepoint']

logx.log_write_object(infubinol_x_series)

# %%
infubinol_y_series = infubinol_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(infubinol_y_series)

# %% [markdown]
# ### **Line Calculations (Ketapril)**

# %%
ketapril_x_series = ketapril_mouse_dataframe['timepoint']

logx.log_write_object(ketapril_x_series)

# %%
ketapril_y_series = ketapril_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(ketapril_y_series)

# %% [markdown]
# ### **Line Calculations (Naftisol)**

# %%
naftisol_x_series = naftisol_mouse_dataframe['timepoint']

logx.log_write_object(naftisol_x_series)

# %%
naftisol_y_series = naftisol_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(naftisol_y_series)

# %% [markdown]
# ### **Line Calculations (Placebo)**

# %%
placebo_x_series = placebo_mouse_dataframe['timepoint']

logx.log_write_object(placebo_x_series)

# %%
placebo_y_series = placebo_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(placebo_y_series)

# %% [markdown]
# ### **Line Calculations (Propriva)**

# %%
propriva_x_series = propriva_mouse_dataframe['timepoint']

logx.log_write_object(propriva_x_series)

# %%
propriva_y_series = propriva_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(propriva_y_series)

# %% [markdown]
# ### **Line Calculations (Ramicane)**

# %%
ramicane_x_series = ramicane_mouse_dataframe['timepoint']

logx.log_write_object(ramicane_x_series)

# %%
ramicane_y_series = ramicane_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(ramicane_y_series)

# %% [markdown]
# ### **Line Calculations (Stelasyn)**

# %%
stelasyn_x_series = stelasyn_mouse_dataframe['timepoint']

logx.log_write_object(stelasyn_x_series)

# %%
stelasyn_y_series = stelasyn_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(stelasyn_y_series)

# %% [markdown]
# ### **Line Calculations (Zoniferol)**

# %%
zoniferol_x_series = zoniferol_mouse_dataframe['timepoint']

logx.log_write_object(zoniferol_x_series)

# %%
zoniferol_y_series = zoniferol_mouse_dataframe['tumor_volume_mm3']

logx.log_write_object(zoniferol_y_series)

# %% [markdown]
# ## **Section 3.5: Display Drug Regimen Treatment of Random Mouse**

# %% [markdown]
# ### **Display Line Plot (Capomulin)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (capomulin_x_series, capomulin_y_series,
     f'Graph 3.5.1: Capomulin Treatment of Mouse {rmid_capomulin_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Ceftamin)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (ceftamin_x_series, ceftamin_y_series,
     f'Graph 3.5.2: Ceftamin Treatment of Mouse {rmid_ceftamin_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Infubinol)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (infubinol_x_series, infubinol_y_series,
     f'Graph 3.5.3: Infubinol Treatment of Mouse {rmid_infubinol_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Ketapril)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (ketapril_x_series, ketapril_y_series,
     f'Graph 3.5.4: Ketapril Treatment of Mouse {rmid_ketapril_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Naftisol)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (naftisol_x_series, naftisol_y_series,
     f'Graph 3.5.5: Naftisol Treatment of Mouse {rmid_naftisol_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Placebo)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (placebo_x_series, placebo_y_series,
     f'Graph 3.5.6: Placebo Treatment of Mouse {rmid_placebo_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Propriva)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (propriva_x_series, propriva_y_series,
     f'Graph 3.5.7: Propriva Treatment of Mouse {rmid_propriva_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Ramicane)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (ramicane_x_series, ramicane_y_series,
     f'Graph 3.5.8: Propriva Treatment of Mouse {rmid_ramicane_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Stelasyn)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (stelasyn_x_series, stelasyn_y_series,
     f'Graph 3.5.9: Stelasyn Treatment of Mouse {rmid_stelasyn_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# ### **Display Line Plot (Zoniferol)**

# %%
matplotlibx.display_line_chart_from_xy_series \
    (zoniferol_x_series, zoniferol_y_series,
     f'Graph 3.5.10: Zoniferol Treatment of Mouse {rmid_zoniferol_string}',
     'Timepoint (days)', 'Tumor Volume (mm3)')

# %% [markdown]
# # <br> **Section 4: Last Tumor Volume by Drug Regimen Statistics**

# %% [markdown]
# ## **Section 4.1: Calculations**

# %% [markdown]
# ### **Most Promising Drug Treatment Regimens**

# %%
# This line of code takes only rows for the four most promising treatment 
# regimens and the placebo and assigns the data to a DataFrame.
promising_treatment_dataframe \
    = clean_medical_study_dataframe \
        .loc \
            [(clean_medical_study_dataframe['drug_regimen'] == 'CAPOMULIN')|
             (clean_medical_study_dataframe['drug_regimen'] == 'RAMICANE')|
             (clean_medical_study_dataframe['drug_regimen'] == 'INFUBINOL')|
             (clean_medical_study_dataframe['drug_regimen'] == 'CEFTAMIN')|
             (clean_medical_study_dataframe['drug_regimen'] == 'PLACEBO'), :]

logx.log_write_object(promising_treatment_dataframe)

# %% [markdown]
# ### **The Last (Greatest) Timepoint for Each Mouse (All)**

# %%
# This line of code uses groupby to group the rows by the last (greatest) timepoint 
# for each mouse ID, retrieves the maximum timepoint for each mouse, and resets 
# the dataframe's index.
maximum_timepoint_dataframe \
    = clean_medical_study_dataframe \
        .groupby('mouse_id')['timepoint'] \
            .max() \
            .reset_index()

logx.log_write_object(maximum_timepoint_dataframe)

# %% [markdown]
# ### **New Merged DataFrame with Last Timepoints (All)**

# %%
merged_medical_study_dataframe \
    = pd.merge \
        (maximum_timepoint_dataframe,
         clean_medical_study_dataframe, 
         on = ['mouse_id', 'timepoint'],
         how = 'left')

logx.log_write_object(merged_medical_study_dataframe)

# %%
# In debug mode, these lines of code check if the mouse IDs in the merged
# medical study dataframe are the same as those in the maximum timepoint 
# per mouse dataframe.
if logx.LOG_FLAG == True:
    
    unique_id_nparray = merged_medical_study_dataframe['mouse_id'].unique()
    
    unique_id_max_timepoint_nparray = maximum_timepoint_dataframe['mouse_id'].unique()
    
    logx.print_and_log_text \
        (str(np.array_equal(unique_id_nparray, unique_id_max_timepoint_nparray)))

# %% [markdown]
# ### **Drug Regimen List (All)**

# %%
all_regimens_string_list \
    = clean_medical_study_dataframe['drug_regimen'] \
         .sort_values(ascending = True) \
         .unique() \
         .tolist()

logx.log_write_object(all_regimens_string_list)

# %% [markdown]
# ### **Populate Tumor Volume List (All)**

# %%
# This for loop cycles through the List of drug regimens, extracts the 
# tumor volume for each regimen as a Series, and appends the series to 
# a List.
tumor_volume_series_list = []

for regimen in all_regimens_string_list:

    regimen_dataframe \
        = merged_medical_study_dataframe \
            .loc[(merged_medical_study_dataframe['drug_regimen'] == regimen), :]

    tumor_volume_series_list.append(regimen_dataframe['tumor_volume_mm3'])

logx.log_write_object(tumor_volume_series_list)

# %% [markdown]
# ## **Section 4.2: Display Tumor Volume Statistics**

# %% [markdown]
# ### **Display Tumor Volume Statistics (All)**

# %%
pymaceuticalsx.display_tumor_volume_statistics \
    (tumor_volume_series_list, all_regimens_string_list, 
     '4.2', 'Tumor Volume')
# Out:
# <style type="text/css">
# #T_84385 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_84385_row0_col0, #T_84385_row0_col1, #T_84385_row0_col2, #T_84385_row0_col3, #T_84385_row0_col4, #T_84385_row0_col5, #T_84385_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_84385">
#   <caption>Table 4.2.1: Tumor Volume Statistics for CAPOMULIN</caption>
#   <thead>
#     <tr>
#       <th id="T_84385_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_84385_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_84385_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_84385_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_84385_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_84385_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_84385_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84385_row0_col0" class="data row0 col0" >32.38</td>
#       <td id="T_84385_row0_col1" class="data row0 col1" >40.16</td>
#       <td id="T_84385_row0_col2" class="data row0 col2" >7.78</td>
#       <td id="T_84385_row0_col3" class="data row0 col3" >38.13</td>
#       <td id="T_84385_row0_col4" class="data row0 col4" >20.70</td>
#       <td id="T_84385_row0_col5" class="data row0 col5" >51.83</td>
#       <td id="T_84385_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a0426 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_a0426_row0_col0, #T_a0426_row0_col1, #T_a0426_row0_col2, #T_a0426_row0_col3, #T_a0426_row0_col4, #T_a0426_row0_col5, #T_a0426_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_a0426">
#   <caption>Table 4.2.2: Tumor Volume Statistics for CEFTAMIN</caption>
#   <thead>
#     <tr>
#       <th id="T_a0426_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_a0426_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_a0426_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_a0426_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_a0426_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_a0426_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_a0426_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a0426_row0_col0" class="data row0 col0" >48.72</td>
#       <td id="T_a0426_row0_col1" class="data row0 col1" >64.30</td>
#       <td id="T_a0426_row0_col2" class="data row0 col2" >15.58</td>
#       <td id="T_a0426_row0_col3" class="data row0 col3" >59.85</td>
#       <td id="T_a0426_row0_col4" class="data row0 col4" >25.36</td>
#       <td id="T_a0426_row0_col5" class="data row0 col5" >87.67</td>
#       <td id="T_a0426_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5511f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_5511f_row0_col0, #T_5511f_row0_col1, #T_5511f_row0_col2, #T_5511f_row0_col3, #T_5511f_row0_col4, #T_5511f_row0_col5, #T_5511f_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_5511f">
#   <caption>Table 4.2.3: Tumor Volume Statistics for INFUBINOL</caption>
#   <thead>
#     <tr>
#       <th id="T_5511f_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_5511f_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_5511f_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_5511f_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_5511f_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_5511f_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_5511f_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5511f_row0_col0" class="data row0 col0" >54.05</td>
#       <td id="T_5511f_row0_col1" class="data row0 col1" >65.53</td>
#       <td id="T_5511f_row0_col2" class="data row0 col2" >11.48</td>
#       <td id="T_5511f_row0_col3" class="data row0 col3" >60.17</td>
#       <td id="T_5511f_row0_col4" class="data row0 col4" >36.83</td>
#       <td id="T_5511f_row0_col5" class="data row0 col5" >82.74</td>
#       <td id="T_5511f_row0_col6" class="data row0 col6" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cc04e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_cc04e_row0_col0, #T_cc04e_row0_col1, #T_cc04e_row0_col2, #T_cc04e_row0_col3, #T_cc04e_row0_col4, #T_cc04e_row0_col5, #T_cc04e_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_cc04e">
#   <caption>Table 4.2.4: Tumor Volume Statistics for KETAPRIL</caption>
#   <thead>
#     <tr>
#       <th id="T_cc04e_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_cc04e_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_cc04e_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_cc04e_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_cc04e_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_cc04e_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_cc04e_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cc04e_row0_col0" class="data row0 col0" >56.72</td>
#       <td id="T_cc04e_row0_col1" class="data row0 col1" >69.87</td>
#       <td id="T_cc04e_row0_col2" class="data row0 col2" >13.15</td>
#       <td id="T_cc04e_row0_col3" class="data row0 col3" >64.49</td>
#       <td id="T_cc04e_row0_col4" class="data row0 col4" >36.99</td>
#       <td id="T_cc04e_row0_col5" class="data row0 col5" >89.60</td>
#       <td id="T_cc04e_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8c676 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_8c676_row0_col0, #T_8c676_row0_col1, #T_8c676_row0_col2, #T_8c676_row0_col3, #T_8c676_row0_col4, #T_8c676_row0_col5, #T_8c676_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_8c676">
#   <caption>Table 4.2.5: Tumor Volume Statistics for NAFTISOL</caption>
#   <thead>
#     <tr>
#       <th id="T_8c676_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_8c676_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_8c676_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_8c676_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_8c676_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_8c676_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_8c676_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8c676_row0_col0" class="data row0 col0" >52.08</td>
#       <td id="T_8c676_row0_col1" class="data row0 col1" >69.56</td>
#       <td id="T_8c676_row0_col2" class="data row0 col2" >17.48</td>
#       <td id="T_8c676_row0_col3" class="data row0 col3" >63.28</td>
#       <td id="T_8c676_row0_col4" class="data row0 col4" >25.85</td>
#       <td id="T_8c676_row0_col5" class="data row0 col5" >95.79</td>
#       <td id="T_8c676_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_68ff5 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_68ff5_row0_col0, #T_68ff5_row0_col1, #T_68ff5_row0_col2, #T_68ff5_row0_col3, #T_68ff5_row0_col4, #T_68ff5_row0_col5, #T_68ff5_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_68ff5">
#   <caption>Table 4.2.6: Tumor Volume Statistics for PLACEBO</caption>
#   <thead>
#     <tr>
#       <th id="T_68ff5_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_68ff5_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_68ff5_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_68ff5_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_68ff5_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_68ff5_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_68ff5_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_68ff5_row0_col0" class="data row0 col0" >52.94</td>
#       <td id="T_68ff5_row0_col1" class="data row0 col1" >68.13</td>
#       <td id="T_68ff5_row0_col2" class="data row0 col2" >15.19</td>
#       <td id="T_68ff5_row0_col3" class="data row0 col3" >62.03</td>
#       <td id="T_68ff5_row0_col4" class="data row0 col4" >30.16</td>
#       <td id="T_68ff5_row0_col5" class="data row0 col5" >90.92</td>
#       <td id="T_68ff5_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d1aa2 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d1aa2_row0_col0, #T_d1aa2_row0_col1, #T_d1aa2_row0_col2, #T_d1aa2_row0_col3, #T_d1aa2_row0_col4, #T_d1aa2_row0_col5, #T_d1aa2_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_d1aa2">
#   <caption>Table 4.2.7: Tumor Volume Statistics for PROPRIVA</caption>
#   <thead>
#     <tr>
#       <th id="T_d1aa2_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_d1aa2_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_d1aa2_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_d1aa2_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_d1aa2_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_d1aa2_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_d1aa2_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d1aa2_row0_col0" class="data row0 col0" >49.12</td>
#       <td id="T_d1aa2_row0_col1" class="data row0 col1" >62.69</td>
#       <td id="T_d1aa2_row0_col2" class="data row0 col2" >13.57</td>
#       <td id="T_d1aa2_row0_col3" class="data row0 col3" >55.59</td>
#       <td id="T_d1aa2_row0_col4" class="data row0 col4" >28.77</td>
#       <td id="T_d1aa2_row0_col5" class="data row0 col5" >83.04</td>
#       <td id="T_d1aa2_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a3dc7 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_a3dc7_row0_col0, #T_a3dc7_row0_col1, #T_a3dc7_row0_col2, #T_a3dc7_row0_col3, #T_a3dc7_row0_col4, #T_a3dc7_row0_col5, #T_a3dc7_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_a3dc7">
#   <caption>Table 4.2.8: Tumor Volume Statistics for RAMICANE</caption>
#   <thead>
#     <tr>
#       <th id="T_a3dc7_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_a3dc7_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_a3dc7_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_a3dc7_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_a3dc7_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_a3dc7_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_a3dc7_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a3dc7_row0_col0" class="data row0 col0" >31.56</td>
#       <td id="T_a3dc7_row0_col1" class="data row0 col1" >40.66</td>
#       <td id="T_a3dc7_row0_col2" class="data row0 col2" >9.10</td>
#       <td id="T_a3dc7_row0_col3" class="data row0 col3" >36.56</td>
#       <td id="T_a3dc7_row0_col4" class="data row0 col4" >17.91</td>
#       <td id="T_a3dc7_row0_col5" class="data row0 col5" >54.31</td>
#       <td id="T_a3dc7_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_71f4f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_71f4f_row0_col0, #T_71f4f_row0_col1, #T_71f4f_row0_col2, #T_71f4f_row0_col3, #T_71f4f_row0_col4, #T_71f4f_row0_col5, #T_71f4f_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_71f4f">
#   <caption>Table 4.2.9: Tumor Volume Statistics for STELASYN</caption>
#   <thead>
#     <tr>
#       <th id="T_71f4f_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_71f4f_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_71f4f_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_71f4f_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_71f4f_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_71f4f_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_71f4f_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_71f4f_row0_col0" class="data row0 col0" >52.48</td>
#       <td id="T_71f4f_row0_col1" class="data row0 col1" >69.10</td>
#       <td id="T_71f4f_row0_col2" class="data row0 col2" >16.63</td>
#       <td id="T_71f4f_row0_col3" class="data row0 col3" >62.19</td>
#       <td id="T_71f4f_row0_col4" class="data row0 col4" >27.54</td>
#       <td id="T_71f4f_row0_col5" class="data row0 col5" >94.04</td>
#       <td id="T_71f4f_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_302b0 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_302b0_row0_col0, #T_302b0_row0_col1, #T_302b0_row0_col2, #T_302b0_row0_col3, #T_302b0_row0_col4, #T_302b0_row0_col5, #T_302b0_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_302b0">
#   <caption>Table 4.2.10: Tumor Volume Statistics for ZONIFEROL</caption>
#   <thead>
#     <tr>
#       <th id="T_302b0_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_302b0_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_302b0_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_302b0_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_302b0_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_302b0_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_302b0_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_302b0_row0_col0" class="data row0 col0" >49.99</td>
#       <td id="T_302b0_row0_col1" class="data row0 col1" >66.79</td>
#       <td id="T_302b0_row0_col2" class="data row0 col2" >16.81</td>
#       <td id="T_302b0_row0_col3" class="data row0 col3" >61.84</td>
#       <td id="T_302b0_row0_col4" class="data row0 col4" >24.78</td>
#       <td id="T_302b0_row0_col5" class="data row0 col5" >92.00</td>
#       <td id="T_302b0_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
matplotlibx.display_boxplots_from_series_list \
    (tumor_volume_series_list,
     all_regimens_string_list,
     'Figure 4.2.1: Tumor Volume (Last) by Drug Regimen Distribution',
     'Drug Regimen', 'Final Tumor Volume (mm3)',
     xticks_rotation_float = 90.0)

# %% [markdown]
# # <br> **Section 5: Last (Greatest) Timepoint  Statistics**

# %% [markdown]
# ## **Section 5.1: Populate Last Timepoint List**

# %%
last_timepoint_series_list = []

for regimen in all_regimens_string_list:

    regimen_dataframe \
        = merged_medical_study_dataframe \
            .loc[(merged_medical_study_dataframe['drug_regimen'] == regimen), :]

    last_timepoint_series_list.append(regimen_dataframe['timepoint'])

logx.log_write_object(last_timepoint_series_list)

# %% [markdown]
# ## **Section 5.2: Display Last (Greatest) Timepoint  Statistics**

# %%
pymaceuticalsx.display_tumor_volume_statistics \
    (last_timepoint_series_list,
     all_regimens_string_list, 
     '5.2', 'Last (Greatest) Timepoint')
# Out:
# <style type="text/css">
# #T_ac91a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_ac91a_row0_col0, #T_ac91a_row0_col1, #T_ac91a_row0_col2, #T_ac91a_row0_col3, #T_ac91a_row0_col4, #T_ac91a_row0_col5, #T_ac91a_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_ac91a">
#   <caption>Table 5.2.1: Last (Greatest) Timepoint Statistics for CAPOMULIN</caption>
#   <thead>
#     <tr>
#       <th id="T_ac91a_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_ac91a_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_ac91a_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_ac91a_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_ac91a_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_ac91a_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_ac91a_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ac91a_row0_col0" class="data row0 col0" >45.00</td>
#       <td id="T_ac91a_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_ac91a_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_ac91a_row0_col3" class="data row0 col3" >45.00</td>
#       <td id="T_ac91a_row0_col4" class="data row0 col4" >45.00</td>
#       <td id="T_ac91a_row0_col5" class="data row0 col5" >45.00</td>
#       <td id="T_ac91a_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_347b8 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_347b8_row0_col0, #T_347b8_row0_col1, #T_347b8_row0_col2, #T_347b8_row0_col3, #T_347b8_row0_col4, #T_347b8_row0_col5, #T_347b8_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_347b8">
#   <caption>Table 5.2.2: Last (Greatest) Timepoint Statistics for CEFTAMIN</caption>
#   <thead>
#     <tr>
#       <th id="T_347b8_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_347b8_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_347b8_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_347b8_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_347b8_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_347b8_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_347b8_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_347b8_row0_col0" class="data row0 col0" >15.00</td>
#       <td id="T_347b8_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_347b8_row0_col2" class="data row0 col2" >30.00</td>
#       <td id="T_347b8_row0_col3" class="data row0 col3" >45.00</td>
#       <td id="T_347b8_row0_col4" class="data row0 col4" >-30.00</td>
#       <td id="T_347b8_row0_col5" class="data row0 col5" >90.00</td>
#       <td id="T_347b8_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d7f87 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d7f87_row0_col0, #T_d7f87_row0_col1, #T_d7f87_row0_col2, #T_d7f87_row0_col3, #T_d7f87_row0_col4, #T_d7f87_row0_col5, #T_d7f87_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_d7f87">
#   <caption>Table 5.2.3: Last (Greatest) Timepoint Statistics for INFUBINOL</caption>
#   <thead>
#     <tr>
#       <th id="T_d7f87_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_d7f87_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_d7f87_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_d7f87_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_d7f87_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_d7f87_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_d7f87_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d7f87_row0_col0" class="data row0 col0" >20.00</td>
#       <td id="T_d7f87_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_d7f87_row0_col2" class="data row0 col2" >25.00</td>
#       <td id="T_d7f87_row0_col3" class="data row0 col3" >30.00</td>
#       <td id="T_d7f87_row0_col4" class="data row0 col4" >-17.50</td>
#       <td id="T_d7f87_row0_col5" class="data row0 col5" >82.50</td>
#       <td id="T_d7f87_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2cc40 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_2cc40_row0_col0, #T_2cc40_row0_col1, #T_2cc40_row0_col2, #T_2cc40_row0_col3, #T_2cc40_row0_col4, #T_2cc40_row0_col5, #T_2cc40_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_2cc40">
#   <caption>Table 5.2.4: Last (Greatest) Timepoint Statistics for KETAPRIL</caption>
#   <thead>
#     <tr>
#       <th id="T_2cc40_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_2cc40_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_2cc40_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_2cc40_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_2cc40_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_2cc40_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_2cc40_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2cc40_row0_col0" class="data row0 col0" >25.00</td>
#       <td id="T_2cc40_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_2cc40_row0_col2" class="data row0 col2" >20.00</td>
#       <td id="T_2cc40_row0_col3" class="data row0 col3" >40.00</td>
#       <td id="T_2cc40_row0_col4" class="data row0 col4" >-5.00</td>
#       <td id="T_2cc40_row0_col5" class="data row0 col5" >75.00</td>
#       <td id="T_2cc40_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3b8cc caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3b8cc_row0_col0, #T_3b8cc_row0_col1, #T_3b8cc_row0_col2, #T_3b8cc_row0_col3, #T_3b8cc_row0_col4, #T_3b8cc_row0_col5, #T_3b8cc_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_3b8cc">
#   <caption>Table 5.2.5: Last (Greatest) Timepoint Statistics for NAFTISOL</caption>
#   <thead>
#     <tr>
#       <th id="T_3b8cc_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_3b8cc_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_3b8cc_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_3b8cc_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_3b8cc_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_3b8cc_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_3b8cc_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3b8cc_row0_col0" class="data row0 col0" >20.00</td>
#       <td id="T_3b8cc_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_3b8cc_row0_col2" class="data row0 col2" >25.00</td>
#       <td id="T_3b8cc_row0_col3" class="data row0 col3" >45.00</td>
#       <td id="T_3b8cc_row0_col4" class="data row0 col4" >-17.50</td>
#       <td id="T_3b8cc_row0_col5" class="data row0 col5" >82.50</td>
#       <td id="T_3b8cc_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cd034 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_cd034_row0_col0, #T_cd034_row0_col1, #T_cd034_row0_col2, #T_cd034_row0_col3, #T_cd034_row0_col4, #T_cd034_row0_col5, #T_cd034_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_cd034">
#   <caption>Table 5.2.6: Last (Greatest) Timepoint Statistics for PLACEBO</caption>
#   <thead>
#     <tr>
#       <th id="T_cd034_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_cd034_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_cd034_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_cd034_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_cd034_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_cd034_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_cd034_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cd034_row0_col0" class="data row0 col0" >20.00</td>
#       <td id="T_cd034_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_cd034_row0_col2" class="data row0 col2" >25.00</td>
#       <td id="T_cd034_row0_col3" class="data row0 col3" >35.00</td>
#       <td id="T_cd034_row0_col4" class="data row0 col4" >-17.50</td>
#       <td id="T_cd034_row0_col5" class="data row0 col5" >82.50</td>
#       <td id="T_cd034_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b213d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b213d_row0_col0, #T_b213d_row0_col1, #T_b213d_row0_col2, #T_b213d_row0_col3, #T_b213d_row0_col4, #T_b213d_row0_col5, #T_b213d_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_b213d">
#   <caption>Table 5.2.7: Last (Greatest) Timepoint Statistics for PROPRIVA</caption>
#   <thead>
#     <tr>
#       <th id="T_b213d_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_b213d_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_b213d_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_b213d_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_b213d_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_b213d_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_b213d_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b213d_row0_col0" class="data row0 col0" >10.00</td>
#       <td id="T_b213d_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_b213d_row0_col2" class="data row0 col2" >35.00</td>
#       <td id="T_b213d_row0_col3" class="data row0 col3" >27.50</td>
#       <td id="T_b213d_row0_col4" class="data row0 col4" >-42.50</td>
#       <td id="T_b213d_row0_col5" class="data row0 col5" >97.50</td>
#       <td id="T_b213d_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_16d6b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_16d6b_row0_col0, #T_16d6b_row0_col1, #T_16d6b_row0_col2, #T_16d6b_row0_col3, #T_16d6b_row0_col4, #T_16d6b_row0_col5, #T_16d6b_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_16d6b">
#   <caption>Table 5.2.8: Last (Greatest) Timepoint Statistics for RAMICANE</caption>
#   <thead>
#     <tr>
#       <th id="T_16d6b_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_16d6b_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_16d6b_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_16d6b_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_16d6b_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_16d6b_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_16d6b_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_16d6b_row0_col0" class="data row0 col0" >45.00</td>
#       <td id="T_16d6b_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_16d6b_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_16d6b_row0_col3" class="data row0 col3" >45.00</td>
#       <td id="T_16d6b_row0_col4" class="data row0 col4" >45.00</td>
#       <td id="T_16d6b_row0_col5" class="data row0 col5" >45.00</td>
#       <td id="T_16d6b_row0_col6" class="data row0 col6" >5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_296a5 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_296a5_row0_col0, #T_296a5_row0_col1, #T_296a5_row0_col2, #T_296a5_row0_col3, #T_296a5_row0_col4, #T_296a5_row0_col5, #T_296a5_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_296a5">
#   <caption>Table 5.2.9: Last (Greatest) Timepoint Statistics for STELASYN</caption>
#   <thead>
#     <tr>
#       <th id="T_296a5_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_296a5_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_296a5_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_296a5_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_296a5_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_296a5_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_296a5_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_296a5_row0_col0" class="data row0 col0" >23.75</td>
#       <td id="T_296a5_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_296a5_row0_col2" class="data row0 col2" >21.25</td>
#       <td id="T_296a5_row0_col3" class="data row0 col3" >37.50</td>
#       <td id="T_296a5_row0_col4" class="data row0 col4" >-8.12</td>
#       <td id="T_296a5_row0_col5" class="data row0 col5" >76.88</td>
#       <td id="T_296a5_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_892a6 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_892a6_row0_col0, #T_892a6_row0_col1, #T_892a6_row0_col2, #T_892a6_row0_col3, #T_892a6_row0_col4, #T_892a6_row0_col5, #T_892a6_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_892a6">
#   <caption>Table 5.2.10: Last (Greatest) Timepoint Statistics for ZONIFEROL</caption>
#   <thead>
#     <tr>
#       <th id="T_892a6_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_892a6_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_892a6_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_892a6_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_892a6_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_892a6_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_892a6_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_892a6_row0_col0" class="data row0 col0" >15.00</td>
#       <td id="T_892a6_row0_col1" class="data row0 col1" >45.00</td>
#       <td id="T_892a6_row0_col2" class="data row0 col2" >30.00</td>
#       <td id="T_892a6_row0_col3" class="data row0 col3" >45.00</td>
#       <td id="T_892a6_row0_col4" class="data row0 col4" >-30.00</td>
#       <td id="T_892a6_row0_col5" class="data row0 col5" >90.00</td>
#       <td id="T_892a6_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
matplotlibx.display_boxplots_from_series_list \
    (last_timepoint_series_list,
     all_regimens_string_list,
     'Figure 5.2.1: Last (Greatest) Timepoint Distribution',
     'Drug Regimen', 'Last (Greatest) Timepoints',
     xticks_rotation_float = 90.0)

# %% [markdown]
# # <br> **Section 6: Data Points Per Mouse Analysis**

# %% [markdown]
# ## **Section 6.1: Mouse Data Points by Drug Regimen**

# %% [markdown]
# ### **Calculate Number of Observed Observatons**

# %%
regimen_count_series = clean_medical_study_dataframe['drug_regimen'].value_counts()

logx.log_write_object(regimen_count_series)

# %% [markdown]
# ### **Display Observed Mouse Timepoints by Drug Regimen**

# %%
bar_colors_string_list \
    = ['darkorange',
       'darkorange', 
       'darkgreen', 
       'darkgreen', 
       'darkgreen', 
       'darkgreen', 
       'darkgreen', 
       'darkgreen', 
       'darkgreen', 
       'darkgreen']

matplotlibx.display_bar_chart_from_series \
    (regimen_count_series,
     'Figure 6.1.1: Drug Regimen by Number of Data Points',
     'Drug Regimen', 'Data Points',
     bar_colors_string_list)

# %% [markdown]
# ## **Section 6.2: Infubinol Statistical Outlier**

# %% [markdown]
# ### **Display Infubinol Statistical Outlier**

# %%
infubinol_outlier_dataframe \
    = merged_medical_study_dataframe \
        .loc[(merged_medical_study_dataframe['drug_regimen'] == 'INFUBINOL') \
             & (merged_medical_study_dataframe['tumor_volume_mm3'] < 40.0), :]

logx.log_write_object(infubinol_outlier_dataframe)

# %%
pandasx.return_formatted_table \
    (infubinol_outlier_dataframe, 'Table 6.2.1: Infubinol Statistical Outlier')
# Out:
# <style type="text/css">
# #T_abac7 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_abac7_row0_col0, #T_abac7_row0_col1, #T_abac7_row0_col2, #T_abac7_row0_col3, #T_abac7_row0_col4, #T_abac7_row0_col5, #T_abac7_row0_col6, #T_abac7_row0_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_abac7">
#   <caption>Table 6.2.1: Infubinol Statistical Outlier</caption>
#   <thead>
#     <tr>
#       <th id="T_abac7_level0_col0" class="col_heading level0 col0" >mouse_id</th>
#       <th id="T_abac7_level0_col1" class="col_heading level0 col1" >timepoint</th>
#       <th id="T_abac7_level0_col2" class="col_heading level0 col2" >drug_regimen</th>
#       <th id="T_abac7_level0_col3" class="col_heading level0 col3" >sex</th>
#       <th id="T_abac7_level0_col4" class="col_heading level0 col4" >age_months</th>
#       <th id="T_abac7_level0_col5" class="col_heading level0 col5" >weight_grams</th>
#       <th id="T_abac7_level0_col6" class="col_heading level0 col6" >tumor_volume_mm3</th>
#       <th id="T_abac7_level0_col7" class="col_heading level0 col7" >metastatic_sites</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_abac7_row0_col0" class="data row0 col0" >c326</td>
#       <td id="T_abac7_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_abac7_row0_col2" class="data row0 col2" >INFUBINOL</td>
#       <td id="T_abac7_row0_col3" class="data row0 col3" >Female</td>
#       <td id="T_abac7_row0_col4" class="data row0 col4" >18</td>
#       <td id="T_abac7_row0_col5" class="data row0 col5" >25.00</td>
#       <td id="T_abac7_row0_col6" class="data row0 col6" >36.32</td>
#       <td id="T_abac7_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Display Statistical Outlier Mouse Records**

# %%
infubinol_outlier_mouse_dataframe \
    = clean_medical_study_dataframe.loc[clean_medical_study_dataframe['mouse_id'] == 'c326', :]

logx.log_write_object(infubinol_outlier_mouse_dataframe)

# %%
pandasx.return_formatted_table \
    (infubinol_outlier_mouse_dataframe, 'Table 6.2.2: Statistical Outlier Mouse Records')
# Out:
# <style type="text/css">
# #T_8e810 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_8e810_row0_col0, #T_8e810_row0_col1, #T_8e810_row0_col2, #T_8e810_row0_col3, #T_8e810_row0_col4, #T_8e810_row0_col5, #T_8e810_row0_col6, #T_8e810_row0_col7, #T_8e810_row1_col0, #T_8e810_row1_col1, #T_8e810_row1_col2, #T_8e810_row1_col3, #T_8e810_row1_col4, #T_8e810_row1_col5, #T_8e810_row1_col6, #T_8e810_row1_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_8e810">
#   <caption>Table 6.2.2: Statistical Outlier Mouse Records</caption>
#   <thead>
#     <tr>
#       <th id="T_8e810_level0_col0" class="col_heading level0 col0" >mouse_id</th>
#       <th id="T_8e810_level0_col1" class="col_heading level0 col1" >drug_regimen</th>
#       <th id="T_8e810_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_8e810_level0_col3" class="col_heading level0 col3" >age_months</th>
#       <th id="T_8e810_level0_col4" class="col_heading level0 col4" >weight_grams</th>
#       <th id="T_8e810_level0_col5" class="col_heading level0 col5" >timepoint</th>
#       <th id="T_8e810_level0_col6" class="col_heading level0 col6" >tumor_volume_mm3</th>
#       <th id="T_8e810_level0_col7" class="col_heading level0 col7" >metastatic_sites</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8e810_row0_col0" class="data row0 col0" >c326</td>
#       <td id="T_8e810_row0_col1" class="data row0 col1" >INFUBINOL</td>
#       <td id="T_8e810_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_8e810_row0_col3" class="data row0 col3" >18</td>
#       <td id="T_8e810_row0_col4" class="data row0 col4" >25.00</td>
#       <td id="T_8e810_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_8e810_row0_col6" class="data row0 col6" >45.00</td>
#       <td id="T_8e810_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_8e810_row1_col0" class="data row1 col0" >c326</td>
#       <td id="T_8e810_row1_col1" class="data row1 col1" >INFUBINOL</td>
#       <td id="T_8e810_row1_col2" class="data row1 col2" >Female</td>
#       <td id="T_8e810_row1_col3" class="data row1 col3" >18</td>
#       <td id="T_8e810_row1_col4" class="data row1 col4" >25.00</td>
#       <td id="T_8e810_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_8e810_row1_col6" class="data row1 col6" >36.32</td>
#       <td id="T_8e810_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **Section 6.3: Range of Data Points per Mouse**

# %% [markdown]
# ### **Calculation**

# %%
minimum_data_points_per_mouse_integer \
    = clean_medical_study_dataframe.groupby('mouse_id')['drug_regimen'].count().min()

maximum_data_points_per_mouse_integer \
    = clean_medical_study_dataframe.groupby('mouse_id')['drug_regimen'].count().max()

# %% [markdown]
# ### **Display Range of Data Points per Mouse**

# %%
logx.print_and_log_text \
    ('\033[1m' \
     + 'The range of data points per mouse is '
     + '{:,}'.format(minimum_data_points_per_mouse_integer)
     + '-{:,}.'.format(maximum_data_points_per_mouse_integer)
     + '\033[0m')
# Out:
# The range of data points per mouse is 1-10.

# %% [markdown]
# ## **Section 6.4: Drug Treatment Regimen by Data Points Per Mouse**

# %% [markdown]
# ### **Mouse ID by Number of Data Points**

# %%
mouse_id_by_data_points_series \
    = clean_medical_study_dataframe.groupby('mouse_id')['drug_regimen'].count()

logx.log_write_object(mouse_id_by_data_points_series)

# %%
mouse_id_by_data_points_dataframe = pd.DataFrame(mouse_id_by_data_points_series)

mouse_id_by_data_points_dataframe.rename \
    (columns = {'Drug Regimen': 'Data Points'},
     inplace = True)

logx.log_write_object(mouse_id_by_data_points_dataframe)

# %% [markdown]
# ### **Display Mouse ID by Number of Data Points**

# %%
pandasx.return_formatted_table \
    (mouse_id_by_data_points_dataframe, 'Table 6.4.1: Mouse ID by Number of Data Points')
# Out:
# <style type="text/css">
# #T_d4d3f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d4d3f_row0_col0, #T_d4d3f_row1_col0, #T_d4d3f_row2_col0, #T_d4d3f_row3_col0, #T_d4d3f_row4_col0, #T_d4d3f_row5_col0, #T_d4d3f_row6_col0, #T_d4d3f_row7_col0, #T_d4d3f_row8_col0, #T_d4d3f_row9_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_d4d3f">
#   <caption>Table 6.4.1: Mouse ID by Number of Data Points</caption>
#   <thead>
#     <tr>
#       <th id="T_d4d3f_level0_col0" class="col_heading level0 col0" >drug_regimen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d4d3f_row0_col0" class="data row0 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row1_col0" class="data row1 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row2_col0" class="data row2 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row3_col0" class="data row3 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row4_col0" class="data row4 col0" >7</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row5_col0" class="data row5 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row6_col0" class="data row6 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row7_col0" class="data row7 col0" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row8_col0" class="data row8 col0" >3</td>
#     </tr>
#     <tr>
#       <td id="T_d4d3f_row9_col0" class="data row9 col0" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Mouse ID Lists**

# %%
mouse_ids_1_to_3_string_list \
    = mouse_id_by_data_points_series \
        [(mouse_id_by_data_points_series >= 1) & (mouse_id_by_data_points_series <= 3)] \
            .index \
            .tolist()

logx.log_write_object(mouse_ids_1_to_3_string_list)

# %%
mouse_ids_4_to_6_string_list \
    = mouse_id_by_data_points_series \
        [(mouse_id_by_data_points_series >= 4) & (mouse_id_by_data_points_series <= 6)] \
            .index \
            .tolist()

logx.log_write_object(mouse_ids_4_to_6_string_list)

# %%
mouse_ids_7_to_9_string_list \
    = mouse_id_by_data_points_series \
        [(mouse_id_by_data_points_series >= 7) & (mouse_id_by_data_points_series <= 9)] \
            .index \
            .tolist()

logx.log_write_object(mouse_ids_7_to_9_string_list)

# %%
mouse_ids_10_string_list \
    = mouse_id_by_data_points_series \
        [mouse_id_by_data_points_series == 10] \
            .index \
            .tolist()

logx.log_write_object(mouse_ids_10_string_list)

# %% [markdown]
# ### **Medical Study Information Based on Data Point Count per Mouse**

# %%
mouse_ids_1_to_3_medical_study_dataframe \
    = clean_medical_study_dataframe \
        .apply(lambda row: row[clean_medical_study_dataframe['mouse_id'].isin(mouse_ids_1_to_3_string_list)])

logx.log_write_object(mouse_ids_1_to_3_medical_study_dataframe)

# %%
mouse_ids_4_to_6_medical_study_dataframe \
    = clean_medical_study_dataframe \
        .apply(lambda row: row[clean_medical_study_dataframe['mouse_id'].isin(mouse_ids_4_to_6_string_list)])

logx.log_write_object(mouse_ids_4_to_6_medical_study_dataframe)

# %%
mouse_ids_7_to_9_medical_study_dataframe \
    = clean_medical_study_dataframe \
        .apply(lambda row: row[clean_medical_study_dataframe['mouse_id'].isin(mouse_ids_7_to_9_string_list)])

logx.log_write_object(mouse_ids_7_to_9_medical_study_dataframe)

# %%
mouse_ids_10_medical_study_dataframe \
    = clean_medical_study_dataframe \
        .apply(lambda row: row[clean_medical_study_dataframe['mouse_id'].isin(mouse_ids_10_string_list)])

logx.log_write_object(mouse_ids_10_medical_study_dataframe)

# %% [markdown]
# ### **Mouse ID/Drug Regimen Information**

# %%
mouse_id_regimen_1_to_3_dataframe \
    = mouse_ids_1_to_3_medical_study_dataframe \
        .groupby(['mouse_id', 'drug_regimen']).size().reset_index()

logx.log_write_object(mouse_id_regimen_1_to_3_dataframe)

# %%
mouse_id_regimen_4_to_6_dataframe \
    = mouse_ids_4_to_6_medical_study_dataframe \
        .groupby(['mouse_id', 'drug_regimen']).size().reset_index()

logx.log_write_object(mouse_id_regimen_4_to_6_dataframe)

# %%
mouse_id_regimen_7_to_9_dataframe \
    = mouse_ids_7_to_9_medical_study_dataframe \
        .groupby(['mouse_id', 'drug_regimen']).size().reset_index()

logx.log_write_object(mouse_id_regimen_7_to_9_dataframe)

# %%
mouse_id_regimen_10_dataframe \
    = mouse_ids_10_medical_study_dataframe \
        .groupby(['mouse_id', 'drug_regimen']).size().reset_index()

logx.log_write_object(mouse_id_regimen_10_dataframe)

# %% [markdown]
# ### **Number of Mice Vs. Drug Treatment Regimen**

# %%
mouse_1_to_3_vs_regimen_series \
    = mouse_id_regimen_1_to_3_dataframe.groupby('drug_regimen')['mouse_id'].count()

mouse_1_to_3_vs_regimen_series.name = '1-3 Data Points'

logx.log_write_object(mouse_1_to_3_vs_regimen_series)

# %%
mouse_4_to_6_vs_regimen_series \
    = mouse_id_regimen_4_to_6_dataframe.groupby('drug_regimen')['mouse_id'].count()

mouse_4_to_6_vs_regimen_series.name = '4-6 Data Points'

logx.log_write_object(mouse_4_to_6_vs_regimen_series)

# %%
mouse_7_to_9_vs_regimen_series \
    = mouse_id_regimen_7_to_9_dataframe.groupby('drug_regimen')['mouse_id'].count()

mouse_7_to_9_vs_regimen_series.name = '7-9 Data Points'

logx.log_write_object(mouse_7_to_9_vs_regimen_series)

# %%
mouse_10_vs_regimen_series \
    = mouse_id_regimen_10_dataframe.groupby('drug_regimen')['mouse_id'].count()

mouse_10_vs_regimen_series.name = '10 Data Points'

logx.log_write_object(mouse_10_vs_regimen_series)

# %% [markdown]
# ### **Drug Treatment Regimen by Data Points Per Mouse**

# %%
mouse_count_vs_regimen_dataframe \
    = pd.concat \
        ([mouse_10_vs_regimen_series, 
          mouse_7_to_9_vs_regimen_series,
          mouse_4_to_6_vs_regimen_series,
          mouse_1_to_3_vs_regimen_series], 
         axis = 1)

logx.log_write_object(mouse_count_vs_regimen_dataframe)

# %% [markdown]
# ### **Display Drug Treatment Regimen by Data Points Per Mouse**

# %%
pandasx \
    .return_formatted_table \
        (mouse_count_vs_regimen_dataframe,
         'Table 6.4.2: Drug Treatment Regimen by Data Point Category (Number of Mice)')
# Out:
# <style type="text/css">
# #T_72472 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_72472_row0_col0, #T_72472_row0_col1, #T_72472_row0_col2, #T_72472_row0_col3, #T_72472_row1_col0, #T_72472_row1_col1, #T_72472_row1_col2, #T_72472_row1_col3, #T_72472_row2_col0, #T_72472_row2_col1, #T_72472_row2_col2, #T_72472_row2_col3, #T_72472_row3_col0, #T_72472_row3_col1, #T_72472_row3_col2, #T_72472_row3_col3, #T_72472_row4_col0, #T_72472_row4_col1, #T_72472_row4_col2, #T_72472_row4_col3, #T_72472_row5_col0, #T_72472_row5_col1, #T_72472_row5_col2, #T_72472_row5_col3, #T_72472_row6_col0, #T_72472_row6_col1, #T_72472_row6_col2, #T_72472_row6_col3, #T_72472_row7_col0, #T_72472_row7_col1, #T_72472_row7_col2, #T_72472_row7_col3, #T_72472_row8_col0, #T_72472_row8_col1, #T_72472_row8_col2, #T_72472_row8_col3, #T_72472_row9_col0, #T_72472_row9_col1, #T_72472_row9_col2, #T_72472_row9_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_72472">
#   <caption>Table 6.4.2: Drug Treatment Regimen by Data Point Category (Number of Mice)</caption>
#   <thead>
#     <tr>
#       <th id="T_72472_level0_col0" class="col_heading level0 col0" >10 Data Points</th>
#       <th id="T_72472_level0_col1" class="col_heading level0 col1" >7-9 Data Points</th>
#       <th id="T_72472_level0_col2" class="col_heading level0 col2" >4-6 Data Points</th>
#       <th id="T_72472_level0_col3" class="col_heading level0 col3" >1-3 Data Points</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_72472_row0_col0" class="data row0 col0" >21</td>
#       <td id="T_72472_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_72472_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_72472_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_72472_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_72472_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_72472_row1_col3" class="data row1 col3" >6</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_72472_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_72472_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_72472_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_72472_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_72472_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_72472_row3_col3" class="data row3 col3" >6</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row4_col0" class="data row4 col0" >13</td>
#       <td id="T_72472_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_72472_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_72472_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row5_col0" class="data row5 col0" >11</td>
#       <td id="T_72472_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_72472_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_72472_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_72472_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_72472_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_72472_row6_col3" class="data row6 col3" >9</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row7_col0" class="data row7 col0" >20</td>
#       <td id="T_72472_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_72472_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_72472_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row8_col0" class="data row8 col0" >11</td>
#       <td id="T_72472_row8_col1" class="data row8 col1" >6</td>
#       <td id="T_72472_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_72472_row8_col3" class="data row8 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_72472_row9_col0" class="data row9 col0" >14</td>
#       <td id="T_72472_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_72472_row9_col2" class="data row9 col2" >6</td>
#       <td id="T_72472_row9_col3" class="data row9 col3" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
bar_colors_string_list = ['darkgreen', 'steelblue', 'purple', 'firebrick']

matplotlibx.display_bar_chart_from_dataframe \
    (mouse_count_vs_regimen_dataframe,
     'Figure 6.4.1: Drug Treatment Regimen by Data Points Per Mouse',
     'Drug Treatment Regimen', 'Number of Mice',
     bar_colors_string_list, True, True)

# %% [markdown]
# ## **Section 6.5: Percentage of Missing Data Points**

# %% [markdown]
# ### **Number of Expected Data Points**

# %%
regimen_count_integer = 10

expected_mice_per_regimen_integer = 25

expected_data_points_per_mouse_count_integer = 10

expected_data_point_total_integer \
    = regimen_count_integer \
        * expected_mice_per_regimen_integer \
        * expected_data_points_per_mouse_count_integer
    
logx.print_and_log_text \
    ('\033[1m' \
     + 'There should be {:,} '.format(expected_data_point_total_integer)
     + 'data points in this animal study.' \
     + '\033[0m')
# Out:
# There should be 2,500 data points in this animal study.

# %% [markdown]
# ### **Number of Actual Data Points**

# %%
current_data_point_total_integer \
    = clean_medical_study_dataframe['mouse_id'].count()

logx.print_and_log_text \
    ('\033[1m' \
     + 'There are {:,} data points '.format(current_data_point_total_integer)
     + 'in this animal study.' \
     + '\033[0m')
# Out:
# There are 1,880 data points in this animal study.

# %% [markdown]
# ### **Display Percentage of Missing Data Points**

# %%
missing_data_point_count_integer \
    = expected_data_point_total_integer - current_data_point_total_integer

missing_data_point_percentage_float \
    = (missing_data_point_count_integer / expected_data_point_total_integer) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'This animal study is missing {:,} data points '.format(missing_data_point_count_integer)
     + 'or {:,.1f}% of the expected total.'.format(missing_data_point_percentage_float) \
     + '\033[0m')
# Out:
# This animal study is missing 620 data points or 24.8% of the expected total.

# %% [markdown]
# # **Section 7: Tumor Volumes vs. Mouse Weights by Drug Regimen**

# %% [markdown]
# ## **Section 7.1: Tumor Volumes (Median) By Drug Regimen**

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Capomulin)**

# %%
capomulin_median_tumor_volume_per_mouse_series \
    = capomulin_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(capomulin_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Ceftamin)**

# %%
ceftamin_median_tumor_volume_per_mouse_series \
    = ceftamin_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(ceftamin_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Infubinol)**

# %%
infubinol_median_tumor_volume_per_mouse_series \
    = infubinol_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(infubinol_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Ketapril)**

# %%
ketapril_median_tumor_volume_per_mouse_series \
    = ketapril_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(ketapril_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Naftisol)**

# %%
naftisol_median_tumor_volume_per_mouse_series \
    = naftisol_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(naftisol_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Placebo)**

# %%
placebo_median_tumor_volume_per_mouse_series \
    = placebo_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(placebo_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Propriva)**

# %%
propriva_median_tumor_volume_per_mouse_series \
    = propriva_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(propriva_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Ramicane)**

# %%
ramicane_median_tumor_volume_per_mouse_series \
    = ramicane_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(ramicane_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Stelasyn)**

# %%
stelasyn_median_tumor_volume_per_mouse_series \
    = stelasyn_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(stelasyn_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ### **Tumor Volumes (Median) By Drug Regimen (Zoniferol)**

# %%
zoniferol_median_tumor_volume_per_mouse_series \
    = zoniferol_study_dataframe.groupby('mouse_id')['tumor_volume_mm3'].median()

logx.log_write_object(zoniferol_median_tumor_volume_per_mouse_series)

# %% [markdown]
# ## **Section 7.2: Mouse Weights (Median) by Drug Regimen**

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Capomulin)**

# %%
capomulin_median_weight_per_mouse_series \
    = capomulin_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(capomulin_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Ceftamin)**

# %%
ceftamin_median_weight_per_mouse_series \
    = ceftamin_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(ceftamin_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Infubinol)**

# %%
infubinol_median_weight_per_mouse_series \
    = infubinol_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(infubinol_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Ketapril)**

# %%
ketapril_median_weight_per_mouse_series \
    = ketapril_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(ketapril_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Naftisol)**

# %%
naftisol_median_weight_per_mouse_series \
    = naftisol_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(naftisol_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Placebo)**

# %%
placebo_median_weight_per_mouse_series \
    = placebo_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(placebo_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Propriva)**

# %%
propriva_median_weight_per_mouse_series \
    = propriva_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(propriva_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Ramicane)**

# %%
ramicane_median_weight_per_mouse_series \
    = ramicane_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(ramicane_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Stelasyn)**

# %%
stelasyn_median_weight_per_mouse_series \
    = stelasyn_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(stelasyn_median_weight_per_mouse_series)

# %% [markdown]
# ### **Mouse Weights (Median) by Drug Regimen (Zoniferol)**

# %%
zoniferol_median_weight_per_mouse_series \
    = zoniferol_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(zoniferol_median_weight_per_mouse_series)

# %% [markdown]
# ## **Section 7.3: Display Tumor Volumes vs. Mouse Weights With Regression**

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Capomulin)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (capomulin_median_weight_per_mouse_series,
     capomulin_median_tumor_volume_per_mouse_series,
     'Graph 7.3.1: Tumor Volumes vs. Mouse Weights With Regression (Capomulin)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 18.5, 36.0)
# Out:
# r-value:     0.7669
# r-squared:   0.5881

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Ceftamin)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (ceftamin_median_weight_per_mouse_series,
     ceftamin_median_tumor_volume_per_mouse_series,
     'Graph 7.3.2: Tumor Volumes vs. Mouse Weights With Regression (Ceftamin)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 49.0)
# Out:
# r-value:     0.0081
# r-squared:   0.0001

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Infubinol)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (infubinol_median_weight_per_mouse_series,
     infubinol_median_tumor_volume_per_mouse_series,
     'Graph 7.3.3: Tumor Volumes vs. Mouse Weights With Regression (Infubinol)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 48.0)
# Out:
# r-value:     -0.0681
# r-squared:   0.0046

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Ketapril)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (ketapril_median_weight_per_mouse_series,
     ketapril_median_tumor_volume_per_mouse_series,
     'Graph 7.3.4: Tumor Volumes vs. Mouse Weights With Regression (Ketapril)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 48.0)
# Out:
# r-value:     -0.0055
# r-squared:   0.0000

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Naftisol)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (naftisol_median_weight_per_mouse_series,
     naftisol_median_tumor_volume_per_mouse_series,
     'Graph 7.3.5: Tumor Volumes vs. Mouse Weights With Regression (Naftisol)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 49.0)
# Out:
# r-value:     -0.1309
# r-squared:   0.0171

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Placebo)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (placebo_median_weight_per_mouse_series,
     placebo_median_tumor_volume_per_mouse_series,
     'Graph 7.3.6: Tumor Volumes vs. Mouse Weights With Regression (Placebo)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 49.0)
# Out:
# r-value:     -0.1195
# r-squared:   0.0143

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Propriva)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (propriva_median_weight_per_mouse_series,
     propriva_median_tumor_volume_per_mouse_series,
     'Graph 7.3.7: Tumor Volumes vs. Mouse Weights With Regression (Propriva)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 48.0)
# Out:
# r-value:     -0.0030
# r-squared:   0.0000

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Ramicane)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (ramicane_median_weight_per_mouse_series,
     ramicane_median_tumor_volume_per_mouse_series,
     'Graph 7.3.8: Tumor Volumes vs. Mouse Weights With Regression (Ramicane)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 19.5, 38.5)
# Out:
# r-value:     0.6917
# r-squared:   0.4784

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Stelasyn)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (stelasyn_median_weight_per_mouse_series,
     stelasyn_median_tumor_volume_per_mouse_series,
     'Graph 7.3.9: Tumor Volumes vs. Mouse Weights With Regression (Stelasyn)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 49.5)
# Out:
# r-value:     0.0623
# r-squared:   0.0039

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights With Regression (Zoniferol)**

# %%
matplotlibx.display_scatter_plot_from_xy_series \
    (zoniferol_median_weight_per_mouse_series,
     zoniferol_median_tumor_volume_per_mouse_series,
     'Graph 7.3.10: Tumor Volumes vs. Mouse Weights With Regression (Zoniferol)',
     'Timepoint (days)', 'Tumor Volume (mm3)', 1, 25.5, 54.0)
# Out:
# r-value:     -0.3136
# r-squared:   0.0983

# %% [markdown]
# ### **Display Tumor Volumes vs. Mouse Weights Plots with High Correlation**

# %%
x_series_list = []
y_series_list = []

title_string_list = []

equation_x_coordinate_float_list = []
equation_y_coordinate_float_list = []


x_series_list.append(capomulin_median_weight_per_mouse_series)
x_series_list.append(ramicane_median_weight_per_mouse_series)

y_series_list.append(capomulin_median_tumor_volume_per_mouse_series)
y_series_list.append(ramicane_median_tumor_volume_per_mouse_series)

title_string_list.append('CAPOMULIN')
title_string_list.append('RAMICANE')

equation_x_coordinate_float_list.append(18.5)
equation_x_coordinate_float_list.append(19.5)

equation_y_coordinate_float_list.append(36.0)
equation_y_coordinate_float_list.append(38.5)

matplotlibx.display_multiple_scatter_plots_from_xy_series_list \
    (x_series_list, y_series_list, title_string_list,
     'Figure 7.3.11: Tumor Volumes vs. Mouse Weights Plots with High Correlation',
     'Weight (g)', 'Tumor Volume (mm3)', 1,
     equation_x_coordinate_float_list, equation_y_coordinate_float_list)
# Out:
# CAPOMULIN:
# r-value:     0.7669
# r-squared:   0.5881
# RAMICANE:
# r-value:     0.6917
# r-squared:   0.4784

# %% [markdown]
# ## **Section 7.4: Mouse Weight Statistics**

# %% [markdown]
# ### **Median Mouse Weights DataFrame**

# %%
median_mouse_weights_by_id_series \
    = clean_medical_study_dataframe.groupby('mouse_id')['weight_grams'].median()

logx.log_write_object(median_mouse_weights_by_id_series)

# %%
drug_regimen_by_id_series \
    = clean_medical_study_dataframe.groupby('mouse_id')['drug_regimen'].unique()

for index, row in enumerate(drug_regimen_by_id_series):
    
    drug_regimen_by_id_series.iloc[index] = row[0]
    
logx.log_write_object(drug_regimen_by_id_series)

# %%
frame_dictionary \
    = {'drug_regimen': drug_regimen_by_id_series.tolist(),
       'weight_grams': median_mouse_weights_by_id_series}

median_mouse_weights_dataframe \
    = pd.DataFrame(frame_dictionary)

# %% [markdown]
# ### **Display Mouse ID by Drug Regimen and Weight**

# %%
pandasx.return_formatted_table \
    (median_mouse_weights_dataframe, 'Table 7.4.0: Mouse ID by Drug Regimen and Weight')
# Out:
# <style type="text/css">
# #T_b886c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b886c_row0_col0, #T_b886c_row0_col1, #T_b886c_row1_col0, #T_b886c_row1_col1, #T_b886c_row2_col0, #T_b886c_row2_col1, #T_b886c_row3_col0, #T_b886c_row3_col1, #T_b886c_row4_col0, #T_b886c_row4_col1, #T_b886c_row5_col0, #T_b886c_row5_col1, #T_b886c_row6_col0, #T_b886c_row6_col1, #T_b886c_row7_col0, #T_b886c_row7_col1, #T_b886c_row8_col0, #T_b886c_row8_col1, #T_b886c_row9_col0, #T_b886c_row9_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_b886c">
#   <caption>Table 7.4.0: Mouse ID by Drug Regimen and Weight</caption>
#   <thead>
#     <tr>
#       <th id="T_b886c_level0_col0" class="col_heading level0 col0" >drug_regimen</th>
#       <th id="T_b886c_level0_col1" class="col_heading level0 col1" >weight_grams</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b886c_row0_col0" class="data row0 col0" >INFUBINOL</td>
#       <td id="T_b886c_row0_col1" class="data row0 col1" >23.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row1_col0" class="data row1 col0" >INFUBINOL</td>
#       <td id="T_b886c_row1_col1" class="data row1 col1" >25.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row2_col0" class="data row2 col0" >PLACEBO</td>
#       <td id="T_b886c_row2_col1" class="data row2 col1" >29.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row3_col0" class="data row3 col0" >CEFTAMIN</td>
#       <td id="T_b886c_row3_col1" class="data row3 col1" >28.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row4_col0" class="data row4 col0" >STELASYN</td>
#       <td id="T_b886c_row4_col1" class="data row4 col1" >29.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row5_col0" class="data row5 col0" >ZONIFEROL</td>
#       <td id="T_b886c_row5_col1" class="data row5 col1" >25.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row6_col0" class="data row6 col0" >RAMICANE</td>
#       <td id="T_b886c_row6_col1" class="data row6 col1" >22.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row7_col0" class="data row7 col0" >RAMICANE</td>
#       <td id="T_b886c_row7_col1" class="data row7 col1" >25.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row8_col0" class="data row8 col0" >KETAPRIL</td>
#       <td id="T_b886c_row8_col1" class="data row8 col1" >30.00</td>
#     </tr>
#     <tr>
#       <td id="T_b886c_row9_col0" class="data row9 col0" >STELASYN</td>
#       <td id="T_b886c_row9_col1" class="data row9 col1" >25.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Populate Median Mouse Weight List**

# %%
mouse_median_weights_series_list = []

for regimen in all_regimens_string_list:

    regimen_study_dataframe \
        = median_mouse_weights_dataframe \
            .loc[(median_mouse_weights_dataframe['drug_regimen'] == regimen), :]

    mouse_median_weights_series_list \
        .append(regimen_study_dataframe['weight_grams'])

logx.log_write_object(mouse_median_weights_series_list)

# %% [markdown]
# ### **Display Mouse Weight Statistics**

# %%
pymaceuticalsx.display_tumor_volume_statistics \
    (mouse_median_weights_series_list,
     all_regimens_string_list, 
     '7.4', 'Mouse Weight')
# Out:
# <style type="text/css">
# #T_44339 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_44339_row0_col0, #T_44339_row0_col1, #T_44339_row0_col2, #T_44339_row0_col3, #T_44339_row0_col4, #T_44339_row0_col5, #T_44339_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_44339">
#   <caption>Table 7.4.1: Mouse Weight Statistics for CAPOMULIN</caption>
#   <thead>
#     <tr>
#       <th id="T_44339_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_44339_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_44339_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_44339_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_44339_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_44339_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_44339_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44339_row0_col0" class="data row0 col0" >17.00</td>
#       <td id="T_44339_row0_col1" class="data row0 col1" >22.00</td>
#       <td id="T_44339_row0_col2" class="data row0 col2" >5.00</td>
#       <td id="T_44339_row0_col3" class="data row0 col3" >21.00</td>
#       <td id="T_44339_row0_col4" class="data row0 col4" >9.50</td>
#       <td id="T_44339_row0_col5" class="data row0 col5" >29.50</td>
#       <td id="T_44339_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_376f9 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_376f9_row0_col0, #T_376f9_row0_col1, #T_376f9_row0_col2, #T_376f9_row0_col3, #T_376f9_row0_col4, #T_376f9_row0_col5, #T_376f9_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_376f9">
#   <caption>Table 7.4.2: Mouse Weight Statistics for CEFTAMIN</caption>
#   <thead>
#     <tr>
#       <th id="T_376f9_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_376f9_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_376f9_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_376f9_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_376f9_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_376f9_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_376f9_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_376f9_row0_col0" class="data row0 col0" >26.00</td>
#       <td id="T_376f9_row0_col1" class="data row0 col1" >28.00</td>
#       <td id="T_376f9_row0_col2" class="data row0 col2" >2.00</td>
#       <td id="T_376f9_row0_col3" class="data row0 col3" >28.00</td>
#       <td id="T_376f9_row0_col4" class="data row0 col4" >23.00</td>
#       <td id="T_376f9_row0_col5" class="data row0 col5" >31.00</td>
#       <td id="T_376f9_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_afef6 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_afef6_row0_col0, #T_afef6_row0_col1, #T_afef6_row0_col2, #T_afef6_row0_col3, #T_afef6_row0_col4, #T_afef6_row0_col5, #T_afef6_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_afef6">
#   <caption>Table 7.4.3: Mouse Weight Statistics for INFUBINOL</caption>
#   <thead>
#     <tr>
#       <th id="T_afef6_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_afef6_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_afef6_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_afef6_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_afef6_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_afef6_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_afef6_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_afef6_row0_col0" class="data row0 col0" >25.00</td>
#       <td id="T_afef6_row0_col1" class="data row0 col1" >29.00</td>
#       <td id="T_afef6_row0_col2" class="data row0 col2" >4.00</td>
#       <td id="T_afef6_row0_col3" class="data row0 col3" >27.00</td>
#       <td id="T_afef6_row0_col4" class="data row0 col4" >19.00</td>
#       <td id="T_afef6_row0_col5" class="data row0 col5" >35.00</td>
#       <td id="T_afef6_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_38b1f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_38b1f_row0_col0, #T_38b1f_row0_col1, #T_38b1f_row0_col2, #T_38b1f_row0_col3, #T_38b1f_row0_col4, #T_38b1f_row0_col5, #T_38b1f_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_38b1f">
#   <caption>Table 7.4.4: Mouse Weight Statistics for KETAPRIL</caption>
#   <thead>
#     <tr>
#       <th id="T_38b1f_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_38b1f_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_38b1f_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_38b1f_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_38b1f_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_38b1f_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_38b1f_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38b1f_row0_col0" class="data row0 col0" >27.00</td>
#       <td id="T_38b1f_row0_col1" class="data row0 col1" >30.00</td>
#       <td id="T_38b1f_row0_col2" class="data row0 col2" >3.00</td>
#       <td id="T_38b1f_row0_col3" class="data row0 col3" >29.00</td>
#       <td id="T_38b1f_row0_col4" class="data row0 col4" >22.50</td>
#       <td id="T_38b1f_row0_col5" class="data row0 col5" >34.50</td>
#       <td id="T_38b1f_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c837f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c837f_row0_col0, #T_c837f_row0_col1, #T_c837f_row0_col2, #T_c837f_row0_col3, #T_c837f_row0_col4, #T_c837f_row0_col5, #T_c837f_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_c837f">
#   <caption>Table 7.4.5: Mouse Weight Statistics for NAFTISOL</caption>
#   <thead>
#     <tr>
#       <th id="T_c837f_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_c837f_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_c837f_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_c837f_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_c837f_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_c837f_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_c837f_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c837f_row0_col0" class="data row0 col0" >26.00</td>
#       <td id="T_c837f_row0_col1" class="data row0 col1" >29.00</td>
#       <td id="T_c837f_row0_col2" class="data row0 col2" >3.00</td>
#       <td id="T_c837f_row0_col3" class="data row0 col3" >27.00</td>
#       <td id="T_c837f_row0_col4" class="data row0 col4" >21.50</td>
#       <td id="T_c837f_row0_col5" class="data row0 col5" >33.50</td>
#       <td id="T_c837f_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_da069 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_da069_row0_col0, #T_da069_row0_col1, #T_da069_row0_col2, #T_da069_row0_col3, #T_da069_row0_col4, #T_da069_row0_col5, #T_da069_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_da069">
#   <caption>Table 7.4.6: Mouse Weight Statistics for PLACEBO</caption>
#   <thead>
#     <tr>
#       <th id="T_da069_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_da069_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_da069_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_da069_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_da069_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_da069_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_da069_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_da069_row0_col0" class="data row0 col0" >27.00</td>
#       <td id="T_da069_row0_col1" class="data row0 col1" >30.00</td>
#       <td id="T_da069_row0_col2" class="data row0 col2" >3.00</td>
#       <td id="T_da069_row0_col3" class="data row0 col3" >28.00</td>
#       <td id="T_da069_row0_col4" class="data row0 col4" >22.50</td>
#       <td id="T_da069_row0_col5" class="data row0 col5" >34.50</td>
#       <td id="T_da069_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e1b31 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_e1b31_row0_col0, #T_e1b31_row0_col1, #T_e1b31_row0_col2, #T_e1b31_row0_col3, #T_e1b31_row0_col4, #T_e1b31_row0_col5, #T_e1b31_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_e1b31">
#   <caption>Table 7.4.7: Mouse Weight Statistics for PROPRIVA</caption>
#   <thead>
#     <tr>
#       <th id="T_e1b31_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_e1b31_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_e1b31_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_e1b31_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_e1b31_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_e1b31_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_e1b31_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e1b31_row0_col0" class="data row0 col0" >26.00</td>
#       <td id="T_e1b31_row0_col1" class="data row0 col1" >29.00</td>
#       <td id="T_e1b31_row0_col2" class="data row0 col2" >3.00</td>
#       <td id="T_e1b31_row0_col3" class="data row0 col3" >27.00</td>
#       <td id="T_e1b31_row0_col4" class="data row0 col4" >21.50</td>
#       <td id="T_e1b31_row0_col5" class="data row0 col5" >33.50</td>
#       <td id="T_e1b31_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5b0e0 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_5b0e0_row0_col0, #T_5b0e0_row0_col1, #T_5b0e0_row0_col2, #T_5b0e0_row0_col3, #T_5b0e0_row0_col4, #T_5b0e0_row0_col5, #T_5b0e0_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_5b0e0">
#   <caption>Table 7.4.8: Mouse Weight Statistics for RAMICANE</caption>
#   <thead>
#     <tr>
#       <th id="T_5b0e0_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_5b0e0_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_5b0e0_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_5b0e0_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_5b0e0_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_5b0e0_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_5b0e0_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b0e0_row0_col0" class="data row0 col0" >17.00</td>
#       <td id="T_5b0e0_row0_col1" class="data row0 col1" >24.00</td>
#       <td id="T_5b0e0_row0_col2" class="data row0 col2" >7.00</td>
#       <td id="T_5b0e0_row0_col3" class="data row0 col3" >19.00</td>
#       <td id="T_5b0e0_row0_col4" class="data row0 col4" >6.50</td>
#       <td id="T_5b0e0_row0_col5" class="data row0 col5" >34.50</td>
#       <td id="T_5b0e0_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_dd403 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_dd403_row0_col0, #T_dd403_row0_col1, #T_dd403_row0_col2, #T_dd403_row0_col3, #T_dd403_row0_col4, #T_dd403_row0_col5, #T_dd403_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_dd403">
#   <caption>Table 7.4.9: Mouse Weight Statistics for STELASYN</caption>
#   <thead>
#     <tr>
#       <th id="T_dd403_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_dd403_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_dd403_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_dd403_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_dd403_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_dd403_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_dd403_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dd403_row0_col0" class="data row0 col0" >27.00</td>
#       <td id="T_dd403_row0_col1" class="data row0 col1" >29.00</td>
#       <td id="T_dd403_row0_col2" class="data row0 col2" >2.00</td>
#       <td id="T_dd403_row0_col3" class="data row0 col3" >28.00</td>
#       <td id="T_dd403_row0_col4" class="data row0 col4" >24.00</td>
#       <td id="T_dd403_row0_col5" class="data row0 col5" >32.00</td>
#       <td id="T_dd403_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c9f90 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c9f90_row0_col0, #T_c9f90_row0_col1, #T_c9f90_row0_col2, #T_c9f90_row0_col3, #T_c9f90_row0_col4, #T_c9f90_row0_col5, #T_c9f90_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_c9f90">
#   <caption>Table 7.4.10: Mouse Weight Statistics for ZONIFEROL</caption>
#   <thead>
#     <tr>
#       <th id="T_c9f90_level0_col0" class="col_heading level0 col0" >lower_quartile</th>
#       <th id="T_c9f90_level0_col1" class="col_heading level0 col1" >upper_quartile</th>
#       <th id="T_c9f90_level0_col2" class="col_heading level0 col2" >interquartile_range</th>
#       <th id="T_c9f90_level0_col3" class="col_heading level0 col3" >median</th>
#       <th id="T_c9f90_level0_col4" class="col_heading level0 col4" >lower_boundary</th>
#       <th id="T_c9f90_level0_col5" class="col_heading level0 col5" >upper_boundary</th>
#       <th id="T_c9f90_level0_col6" class="col_heading level0 col6" >outlier_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c9f90_row0_col0" class="data row0 col0" >27.00</td>
#       <td id="T_c9f90_row0_col1" class="data row0 col1" >29.00</td>
#       <td id="T_c9f90_row0_col2" class="data row0 col2" >2.00</td>
#       <td id="T_c9f90_row0_col3" class="data row0 col3" >28.00</td>
#       <td id="T_c9f90_row0_col4" class="data row0 col4" >24.00</td>
#       <td id="T_c9f90_row0_col5" class="data row0 col5" >32.00</td>
#       <td id="T_c9f90_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
matplotlibx.display_boxplots_from_series_list \
    (mouse_median_weights_series_list,
     all_regimens_string_list,
     'Figure 7.4.1: Mouse Weight Distributions for Each Treatment Group',
     'Drug Regimen', 'Weight (g)',
     xticks_rotation_float = 90.0)

# %% [markdown]
# # <br> **Section 8: Male vs. Female Mouse Distribution**

# %% [markdown]
# ## **Section 8.1: Mouse Count by Gender for Each Regimen**

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Capomulin)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'CAPOMULIN'), :]

capomulin_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Ceftamin)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'CEFTAMIN'), :]

ceftamin_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Infubinol)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'INFUBINOL'), :]

infubinol_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Ketapril)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'KETAPRIL'), :]

ketapril_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Naftisol)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'NAFTISOL'), :]

naftisol_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Placebo)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'PLACEBO'), :]

placebo_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Propriva)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'PROPRIVA'), :]

propriva_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Ramicane)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'RAMICANE'), :]

ramicane_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Stelasyn)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'STELASYN'), :]

stelasyn_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (Zoniferol)**

# %%
treatment_regimens_dataframe \
    = clean_medical_study_dataframe \
        .loc[(clean_medical_study_dataframe['drug_regimen'] == 'ZONIFEROL'), :]

zoniferol_mouse_count_by_gender_series \
    = treatment_regimens_dataframe['sex'].value_counts()

logx.log_write_object(treatment_regimens_dataframe)

# %% [markdown]
# ### **Calculate Mouse Count by Gender (All)**

# %%
mouse_count_by_gender_series \
    = clean_medical_study_dataframe['sex'].value_counts()

logx.log_write_object(mouse_count_by_gender_series)

# %% [markdown]
# ### **Gender Count Distribution DataFrame**

# %%
frame_dictionary \
    = {'capomulin': capomulin_mouse_count_by_gender_series,
       'ceftamin': ceftamin_mouse_count_by_gender_series,
       'infubinol': infubinol_mouse_count_by_gender_series,
       'ketapril': ketapril_mouse_count_by_gender_series,
       'naftisol': naftisol_mouse_count_by_gender_series,
       'placebo': placebo_mouse_count_by_gender_series,
       'propriva': propriva_mouse_count_by_gender_series,
       'ramicane': ramicane_mouse_count_by_gender_series,
       'stelasyn': stelasyn_mouse_count_by_gender_series,
       'zoniferol': zoniferol_mouse_count_by_gender_series}

mouse_gender_count_distribution_dataframe = pd.DataFrame(frame_dictionary)

# %% [markdown]
# ### **Display Mouse Gender Count Distribution by Drug Regimen**

# %%
pandasx.return_formatted_table \
    (mouse_gender_count_distribution_dataframe,
     'Table 8.1.1: Mouse Gender Count Distribution by Drug Regimen', 10, False)
# Out:
# <style type="text/css">
# #T_cdb22 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_cdb22_row0_col0, #T_cdb22_row0_col1, #T_cdb22_row0_col2, #T_cdb22_row0_col3, #T_cdb22_row0_col4, #T_cdb22_row0_col5, #T_cdb22_row0_col6, #T_cdb22_row0_col7, #T_cdb22_row0_col8, #T_cdb22_row0_col9, #T_cdb22_row1_col0, #T_cdb22_row1_col1, #T_cdb22_row1_col2, #T_cdb22_row1_col3, #T_cdb22_row1_col4, #T_cdb22_row1_col5, #T_cdb22_row1_col6, #T_cdb22_row1_col7, #T_cdb22_row1_col8, #T_cdb22_row1_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_cdb22">
#   <caption>Table 8.1.1: Mouse Gender Count Distribution by Drug Regimen</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdb22_level0_col0" class="col_heading level0 col0" >capomulin</th>
#       <th id="T_cdb22_level0_col1" class="col_heading level0 col1" >ceftamin</th>
#       <th id="T_cdb22_level0_col2" class="col_heading level0 col2" >infubinol</th>
#       <th id="T_cdb22_level0_col3" class="col_heading level0 col3" >ketapril</th>
#       <th id="T_cdb22_level0_col4" class="col_heading level0 col4" >naftisol</th>
#       <th id="T_cdb22_level0_col5" class="col_heading level0 col5" >placebo</th>
#       <th id="T_cdb22_level0_col6" class="col_heading level0 col6" >propriva</th>
#       <th id="T_cdb22_level0_col7" class="col_heading level0 col7" >ramicane</th>
#       <th id="T_cdb22_level0_col8" class="col_heading level0 col8" >stelasyn</th>
#       <th id="T_cdb22_level0_col9" class="col_heading level0 col9" >zoniferol</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdb22_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_cdb22_row0_col0" class="data row0 col0" >128</td>
#       <td id="T_cdb22_row0_col1" class="data row0 col1" >92</td>
#       <td id="T_cdb22_row0_col2" class="data row0 col2" >95</td>
#       <td id="T_cdb22_row0_col3" class="data row0 col3" >58</td>
#       <td id="T_cdb22_row0_col4" class="data row0 col4" >86</td>
#       <td id="T_cdb22_row0_col5" class="data row0 col5" >102</td>
#       <td id="T_cdb22_row0_col6" class="data row0 col6" >61</td>
#       <td id="T_cdb22_row0_col7" class="data row0 col7" >74</td>
#       <td id="T_cdb22_row0_col8" class="data row0 col8" >107</td>
#       <td id="T_cdb22_row0_col9" class="data row0 col9" >119</td>
#     </tr>
#     <tr>
#       <th id="T_cdb22_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_cdb22_row1_col0" class="data row1 col0" >102</td>
#       <td id="T_cdb22_row1_col1" class="data row1 col1" >86</td>
#       <td id="T_cdb22_row1_col2" class="data row1 col2" >83</td>
#       <td id="T_cdb22_row1_col3" class="data row1 col3" >130</td>
#       <td id="T_cdb22_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_cdb22_row1_col5" class="data row1 col5" >79</td>
#       <td id="T_cdb22_row1_col6" class="data row1 col6" >87</td>
#       <td id="T_cdb22_row1_col7" class="data row1 col7" >154</td>
#       <td id="T_cdb22_row1_col8" class="data row1 col8" >74</td>
#       <td id="T_cdb22_row1_col9" class="data row1 col9" >63</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Gender Percent Distribution DataFrame**

# %%
mouse_gender_percent_distribution_dataframe \
    = mouse_gender_count_distribution_dataframe \
        .apply(lambda x: x/sum(x)*100, axis = 0)

display_dataframe \
    = mouse_gender_percent_distribution_dataframe.copy()

temp_string_list = [x.lower() for x in all_regimens_string_list]

for regimen in temp_string_list:
    
    display_dataframe.loc[:, regimen] = display_dataframe[regimen]

# %% [markdown]
# ### **Display Mouse Gender Percent Distribution by Drug Regimen**

# %%
pandasx.return_formatted_table \
    (display_dataframe, 'Table 8.1.2: Mouse Gender Percent Distribution by Drug Regimen', 10, False)
# Out:
# <style type="text/css">
# #T_17c9e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_17c9e_row0_col0, #T_17c9e_row0_col1, #T_17c9e_row0_col2, #T_17c9e_row0_col3, #T_17c9e_row0_col4, #T_17c9e_row0_col5, #T_17c9e_row0_col6, #T_17c9e_row0_col7, #T_17c9e_row0_col8, #T_17c9e_row0_col9, #T_17c9e_row1_col0, #T_17c9e_row1_col1, #T_17c9e_row1_col2, #T_17c9e_row1_col3, #T_17c9e_row1_col4, #T_17c9e_row1_col5, #T_17c9e_row1_col6, #T_17c9e_row1_col7, #T_17c9e_row1_col8, #T_17c9e_row1_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_17c9e">
#   <caption>Table 8.1.2: Mouse Gender Percent Distribution by Drug Regimen</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17c9e_level0_col0" class="col_heading level0 col0" >capomulin</th>
#       <th id="T_17c9e_level0_col1" class="col_heading level0 col1" >ceftamin</th>
#       <th id="T_17c9e_level0_col2" class="col_heading level0 col2" >infubinol</th>
#       <th id="T_17c9e_level0_col3" class="col_heading level0 col3" >ketapril</th>
#       <th id="T_17c9e_level0_col4" class="col_heading level0 col4" >naftisol</th>
#       <th id="T_17c9e_level0_col5" class="col_heading level0 col5" >placebo</th>
#       <th id="T_17c9e_level0_col6" class="col_heading level0 col6" >propriva</th>
#       <th id="T_17c9e_level0_col7" class="col_heading level0 col7" >ramicane</th>
#       <th id="T_17c9e_level0_col8" class="col_heading level0 col8" >stelasyn</th>
#       <th id="T_17c9e_level0_col9" class="col_heading level0 col9" >zoniferol</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17c9e_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_17c9e_row0_col0" class="data row0 col0" >55.65</td>
#       <td id="T_17c9e_row0_col1" class="data row0 col1" >51.69</td>
#       <td id="T_17c9e_row0_col2" class="data row0 col2" >53.37</td>
#       <td id="T_17c9e_row0_col3" class="data row0 col3" >30.85</td>
#       <td id="T_17c9e_row0_col4" class="data row0 col4" >46.24</td>
#       <td id="T_17c9e_row0_col5" class="data row0 col5" >56.35</td>
#       <td id="T_17c9e_row0_col6" class="data row0 col6" >41.22</td>
#       <td id="T_17c9e_row0_col7" class="data row0 col7" >32.46</td>
#       <td id="T_17c9e_row0_col8" class="data row0 col8" >59.12</td>
#       <td id="T_17c9e_row0_col9" class="data row0 col9" >65.38</td>
#     </tr>
#     <tr>
#       <th id="T_17c9e_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_17c9e_row1_col0" class="data row1 col0" >44.35</td>
#       <td id="T_17c9e_row1_col1" class="data row1 col1" >48.31</td>
#       <td id="T_17c9e_row1_col2" class="data row1 col2" >46.63</td>
#       <td id="T_17c9e_row1_col3" class="data row1 col3" >69.15</td>
#       <td id="T_17c9e_row1_col4" class="data row1 col4" >53.76</td>
#       <td id="T_17c9e_row1_col5" class="data row1 col5" >43.65</td>
#       <td id="T_17c9e_row1_col6" class="data row1 col6" >58.78</td>
#       <td id="T_17c9e_row1_col7" class="data row1 col7" >67.54</td>
#       <td id="T_17c9e_row1_col8" class="data row1 col8" >40.88</td>
#       <td id="T_17c9e_row1_col9" class="data row1 col9" >34.62</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **Section 8.2: DisplayMale vs. Female Mouse Distribution**

# %% [markdown]
# ### **Display Female vs. Male Distribution  (All)**

# %%
pie_colors_string_list = ['steelblue', 'firebrick']

explode_tuple = (0.02, 0.02)

matplotlibx.display_pie_chart_from_series \
    (mouse_count_by_gender_series,
     'Figure 8.2.0: Male vs. Female Mouse Distribution (All)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Capomulin)**

# %%
pie_colors_string_list = ['firebrick', 'steelblue']

explode_tuple = (0.02, 0.02)

matplotlibx.display_pie_chart_from_series \
    (capomulin_mouse_count_by_gender_series, 
     'Figure 8.2.1: Male vs. Female Mouse Distribution (Capomulin)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Ceftamin)**

# %%
matplotlibx.display_pie_chart_from_series \
    (ceftamin_mouse_count_by_gender_series, 
     'Figure 8.2.2: Male vs. Female Mouse Distribution (Ceftamin)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Infubinol)**

# %%
matplotlibx.display_pie_chart_from_series \
    (infubinol_mouse_count_by_gender_series, 
     'Figure 8.2.3: Male vs. Female Mouse Distribution (Infubinol)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Ketapril)**

# %%
matplotlibx.display_pie_chart_from_series \
    (ketapril_mouse_count_by_gender_series, 
     'Figure 8.2.4: Male vs. Female Mouse Distribution (Ketapril)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Naftisol)**

# %%
matplotlibx.display_pie_chart_from_series \
    (naftisol_mouse_count_by_gender_series, 
     'Figure 8.2.5: Male vs. Female Mouse Distribution (Naftisol)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Placebo)**

# %%
matplotlibx.display_pie_chart_from_series \
    (placebo_mouse_count_by_gender_series, 
     'Figure 8.2.6: Male vs. Female Mouse Distribution (Placebo)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Propriva)**

# %%
matplotlibx.display_pie_chart_from_series \
    (propriva_mouse_count_by_gender_series, 
     'Figure 8.2.7: Male vs. Female Mouse Distribution (Propriva)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Ramicane)**

# %%
matplotlibx.display_pie_chart_from_series \
    (ramicane_mouse_count_by_gender_series, 
     'Figure 8.2.8: Male vs. Female Mouse Distribution (Ramicane)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Stelasyn)**

# %%
matplotlibx.display_pie_chart_from_series \
    (stelasyn_mouse_count_by_gender_series, 
     'Figure 8.2.9: Male vs. Female Mouse Distribution (Stelasyn)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (Zoniferol)**

# %%
matplotlibx.display_pie_chart_from_series \
    (zoniferol_mouse_count_by_gender_series, 
     'Figure 8.2.10: Male vs. Female Mouse Distribution (Zoniferol)',
     pie_colors_string_list, explode_tuple)

# %% [markdown]
# ### **Display Female vs. Male Distribution (All)**

# %%
bar_colors_string_list = ['firebrick', 'steelblue']

matplotlibx.display_bar_chart_from_dataframe \
    (mouse_gender_percent_distribution_dataframe.transpose(),
     'Figure 8.2.11: Male vs. Female Mouse Distribution',
     'Drug Regimen', 'Percent of Total (%)',
     bar_colors_string_list, True)

# %%
#logx.end_program()
